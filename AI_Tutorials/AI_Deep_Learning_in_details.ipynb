# %% [markdown]
# # Ai Deep Learning in details
#
# Ma yek Neural network darim .
#
# Masalamon input-output hast k ma be donbale rabete ee beyne input va output hastim
#
# outpute ma mitone gosaste , daste daste -> daste bandi (classsification)
# outpute ma peyvaste bashe , continious --> regression
#
# dar har do soorat ma yek chizi mikhahim k rabete ro yad begire (Training phase , fitting phase)
#
# badesh yek boxe , vaghty beheshvorodi midim , bezare too rabete khoroji bede
#
# behesh 30 ta resulte breast cancer --> badkhime, khosh khim . [bijnary classification] <br>
# 4 ta feature az gol --> gol kodom gole (3 no gol) [multi - class classification] <br>
# 10 ta feature yek khone too california --> gheymate khone [regression] <br>
#
#
# Box tarafim.--> boxe ma mananad emaghze ma tashkil shode az laye haye neuron darand
#
#
#
#
# Neuron --> yek chizi hast k vorodi haye mokhtalef migire , har vorodi yek weight (vazn) ahamiat
# bad baham sum mishan --> z = w1*x1 + w2*x2+...+ wnxn badesh mire zire yek activation function
# (non linear) --> a = f(z) --> mire  neurone badi
#
#
# kole networkemon chan laye dare , laye ye aval , input layer (k b andazeye soton haye vorodi (x)) feature (vizhegi)
#
# hidden layers darim
#
# Output layer --> b tedade outputi k drim, chan daste , 10 daste 10 neuron. 1 output --> 1 neuron
#
#
# ![neural_net](https://assets.ibm.com/is/image/ibm/ICLH_Diagram_Batch_01_03-DeepNeuralNetwork:16x9?fmt=png-alpha&dpr=on%2C2&wid=1536&hei=864)

# %% [markdown]
# Har neuron dakhelehs in etefagh miofte. VORODI ha zarb dar weight (ahamiateshon) mishan va jam mishan va badesh miran zire yek activation function (non linear) va khoroji midahan
#
#
# ![one_neuron_logic](https://d3lkc3n5th01x7.cloudfront.net/wp-content/uploads/2023/05/30234805/What-are-neural-networks-Banner.svg)

# %% [markdown]
# Yek networke kamel daram, zamani k yek data daram , masalan khane ye california yedone (metrazh : 100 , balcony metrazh : 50 , rate crime(jorm): 86) --> Ntwork , zarb mishan
#
# Layer 1 :
# $$
# 100*w_{11}+50*w_{12} +86*w_{13} +b_{11} = n_{1_1}
# $$
#
# $$
# 100*w_{21}+50*w_{22} +86*w_{23} +b_{12} = n_{1_2}
# $$
# $$
# 100*w_{31}+50*w_{32} +86*_{w33} +b_{13} = n_{1_3}
# $$
#
#
# Layer 2 :
# $$
# n_{1_1}*w_{211} + n_{1_2}*w_{212} + n_{1_3}*w_{213} + b_{21} = n_{2_1}
# $$
#
# $$
# n_{1_1}*w_{221} + n_{1_2}*w_{222} + n_{1_3}*w_{223} + b_{22} = n_{2_2}
# $$
#
# $$
# n_{1_1}*w_{231} + n_{1_2}*w_{232} + n_{1_3}*w_{233} + b_{23} = n_{2_3}
# $$
#
#
# Output Layer :
# $$
# n_{2_1} * w_{31} + n_{2_2} * w_{32} + n_{2_3} * w_{33} + b_{31} = n_{output}
# $$
#
# dar nahayat vaghty vorodi x haro midim --> 3 ta neuron --> 3 neuron adad --> 1 neuron --< output -> khoroji
#
#
# yek box hast , x haro vared mikonim , y ro mide.
#
# agar weight ha va bias ha kh daghigh bashan , masalan (metrazh : 100 , balcony metrazh : 50 , rate crime(jorm): 86)  , khoroji , gheymae khoen rdoros bedde 80 000 .
#
# Dar che soorat in weight ha va bias ha doros mitonan bashan?
#
# Ma bayad train konim rooye data ha ta in weight ha va bias ha bedast baiayd
#
# ![neuraL_netsarchitecture2](https://www.researchgate.net/profile/Adem-Tekerek-2/publication/335903047/figure/fig1/AS:805611931443200@1569084260672/Proposed-artificial-neural-network-model-3-10-1-Neural-network-weight-vectors-are.png)

# %% [markdown]
# Pas ma aval yek weight haye random mizarim va shoro mikonim (random initialization) , weight ha va bias ha besoorate random hastand , pas vaghty x ro vared mikoni, output k az formole $$n_{output} = n_{2_1} * w_{31} + n_{2_2} * w_{32} + n_{2_3} * w_{33} + b_{31} $$  , hame weight ha va bias ha fk kon randome, pas ma yek khoroji darim beheh migan y hat y^ in yani pishbinie, kh kh bayad adade parti beshe, masalan hamon 100 , 50 , 86 --> 86000 dollar , 3 . 3298237982798327297 choon random hastan .
#
# pas az koja bayasd neural net befahme eshtebah mikone? bayad yek chizi dahste bashe k ba vagheiat biad mogahyese kone , **Loss fucntion** , oon pishbini ro ba vagheiat mire tafavotesh ro hesab mikone.
#
#
#
# ## MSE (Mean squared error)
#
# in baraye regression miabshad va formulesh ine
#
# $$MSE = \frac{1}{n} *  \sum{(y-\hat{y})^{2}}$$
#
# miad oon pishbinisho menhaye vagheiat mikone be tavane 2 . (chnata data) miangineshono in karo mikone, yek ekhtelafe morabae az ekhtalfsho beyne vagheiat va pishbini --> yek chizi darim k fasele ro mide behemon
#
# in moshkelesh --> squared mikone, ag kh kh dade e part bashe ,
#
# 80 K
# 30 K
# 50 K
#
# 40 Million dollar --> lossso kh kharab mikone
#
# sensetive to outliers (hasas hast b dasde haye part)
#
# ## MAE (Mean absolute error)
#
# $$MAE = \frac{1}{n} \sum{|y-\hat{y}|}$$
# miad faseley beyne pishbini va vagheiat ro bsorate motlagh migiree
#
#
# ## Binary Cross Entropy (BSE)
#
# ma classification va b soroat ekhas, binary classification, 2 ta
#
# $$BCE = -[ylog(\hat{y}) + (1-y) log(1-\hat{y})$$
#
# shoma ag pishbinit 1 bashe khodetam 1 psihbini koni -->0 , khodst 0 bashi pishbiit 0 --> 0 . loss --> baraye
#
# choon beyne 2 class --> ya yek class 0 , 1 . dog 0 cat 1 . probability dog 0.8 , cat 0.2 .
#
#
#
# ## Categorial Cross Entropy
#
# multi class darid mitonid biayd , 2.5 , 1 . , 0.2 -> softmax --> 0.8 , 0.15 , 0.05 . cat :0.8 , dog : 0.15 , horse :0.05 .
#
# vcagheiat is cat --> (1,0,0)
#
# y^ = (0.8 , 0.15 , 0.05)
#
# y = (1,0 ,0)
#
# $$Loss = - \sum{y_{i}log(\hat{y}_{i})}$$
#
#
#
# Loss --> yek tabe ee hats k miad ekhtelafe beyen pishbini va vagheiat ro hesab mikone . hala ag regression bashe, fasleye MSE (b tavan2 ) MAE (motlagh) , ag pishbini classiication , BCE , Categorial cross entropy fasleye beyne probability haro ehsab kone.
#
#
# Ma yek networke kamelan random dashitm, vorodi midim dakhel yek khoroji mide (avalesh aprt hast) W0 B0 --> {w01,w02,....} {b0}
#
# Y^ = F(W0 * X + B0)
#
# ba w ha va b haye random, x ro vared krdid -> pishbini krde.
#
# mire to loss, ba vagheiat --> adadi mide --> **Error** migoyand.
#
#
# yek bar inkaro kardi behesh migan **Feed Forward**

# %% [markdown]
# ![error_back](https://media.licdn.com/dms/image/v2/D5612AQECXl0DLimxgQ/article-cover_image-shrink_600_2000/article-cover_image-shrink_600_2000/0/1726329287502?e=2147483647&v=beta&t=T-f2b7Omn7oQylTvfrBu5zNw-xlIrizWLCnPoO1Jpcc)

# %% [markdown]
# Har node , sahmesh az in errror chegahdre? baste be weighti k dare,
# error = 200
#
# node 1 --> weight 0.4 , w2:0.3 , w3: 0.3
#
# node1 -- > E1 --> 0.4 * 200 = 80  , E 2=60 , E3= 60
#
# aghab aghab aghab --> Back propagation error --> b agha error ro hesab mikonam baraye har neuron (node)
#
# dar ch soorat weight mitone behtr beshe? dar soorati k dar jahati oon ro update konim k loss kam beshe, gradient descent (gradian kaheshi) , gradiane Loss / weight ro begirim va dar rastaye menhash , harkat konim
#
# $$W_{new} = W_{old} - learning_rate * \frac{Ro Loss}{ro W}$$
# $$B_{new} = B_{old} - learning_rate * \frac{Ro Loss}{ro B}$$
#
# bar asase chain rules :
# $$\frac{Ro Loss}{ro W}  =  \frac{ro Loss}{ro Z} * \frac{ro Z}{ro W} $$
#
#
#
# Ma raftim loss ro baraye output nahaei hesab krdim, back propagation zadim va baraye har neuron bar asase sahmesh (weight) errror  (loss) ro hesab krdimm , hala omdim moshtaghe loss bar oon wieght o bias ro hesab krdim. hala weight va bias ro dar jahate leanring rate * loss (oshtagh) -> update kardim --> W1 , B1 {w10,w11,w12,...} {b1}
#
# yekseri weighto bias random dashtim ina behtr shodan , roye dataee
#
#
# hamin hey iteration (epoch) hey done done --> ta jaei k loss kh kh kam mishe va ma b noghteye behine miresim --> W , B
#
#
# kole iteration m--> Feed forward --> Back propagation  [weight and bias optimziation (update)]
#
# ![minimum_gradient_descent](https://editor.analyticsvidhya.com/uploads/97106gd4.jpeg)
#
# Behtarin W , B bedast miasd --> agar tina optimize tarin bashan , yani ina weight, bias ha bar asase datye ma learn shodan in parametrs ha k paein taein loss --> paentarin ekhtelaf beyne pishbini va vagheiat , chizi pishbini mikonan kh nazdik b vagheiat hast
#
#
#
# Yek data , (new) --> BOX (Neural newtork)--> zarb dar tamame in weight ha va bias ha bbeshan (hamoon weighto bais hay edgahighi ) ---> N output --> pishbini . methrazo... --> output --> 83 K (pishbini)
#
# yani rabeteye beyne vorodi va khorojji dar hamin parametr hae hast k neural network learn (yad) karde az roye dataye traininge ma.

# %% [markdown]
# ------------
# ------------
# ------------
# # Activation Functions
#
# Agar faghat har neuron zarb dar weight + Bias beshe bad b laye haye badi bere , age 1000 laye ham bezarim farghi bayek laye ham nadare. khati dar kahti khati , w1 * w2 * w3 = W
#
#
# Layer 1 :
# $$
# 100*w_{11}+50*w_{12} +86*w_{13} +b_{11} = n_{1_1}
# $$
#
# $$
# 100*w_{21}+50*w_{22} +86*w_{23} +b_{12} = n_{1_2}
# $$
# $$
# 100*w_{31}+50*w_{32} +86*_{w33} +b_{13} = n_{1_3}
# $$
#
#
# Layer 2 :
# $$
# n_{1_1}*w_{211} + n_{1_2}*w_{212} + n_{1_3}*w_{213} + b_{21} = n_{2_1}
# $$
#
# $$
# n_{1_1}*w_{221} + n_{1_2}*w_{222} + n_{1_3}*w_{223} + b_{22} = n_{2_2}
# $$
#
# $$
# n_{1_1}*w_{231} + n_{1_2}*w_{232} + n_{1_3}*w_{233} + b_{23} = n_{2_3}
# $$
#
#
# Output Layer :
# $$
# n_{2_1} * w_{31} + n_{2_2} * w_{32} + n_{2_3} * w_{33} + b_{31} = n_{output}
# $$
#
#
#
#
# Bejaye n ha adade khodeshono mizarrim
# $$
# n_{2_1} * w_{31} + n_{2_2} * w_{32} + n_{2_3} * w_{33} + b_{31} = n_{output}
# $$
#
#
#
# $$
# (n_{1_1}*w_{211} + n_{1_2}*w_{212} + n_{1_3}*w_{213} + b_{21})* w_{31} + (n_{1_1}*w_{221} + n_{1_2}*w_{222} + n_{1_3}*w_{223} + b_{22}) * w_{32} +  (n_{1_1}*w_{231} + n_{1_2}*w_{232} + n_{1_3}*w_{233} + b_{23}) * w_{33} + b_{31} = n_{output}
# $$
#
#
#
# $$
# n_{1_1}*w_{211}* w_{31}+ n_{1_2}*w_{212}* w_{31} + n_{1_3}*w_{213}* w_{31} + b_{21}* w_{31}  + n_{1_1}*w_{221}* w_{32} + n_{1_2}*w_{222}* w_{32} + n_{1_3}*w_{223}* w_{32} + b_{22}* w_{32} +  n_{1_1}*w_{231}*w_{33} + n_{1_2}*w_{232}*w_{33} + n_{1_3}*w_{233}*w_{33} + b_{23}*w_{33} + b_{31} = n_{output}
# $$
#
#
# $$
# n_{1_1} * (w_{211}* w_{31} + w_{221}* w_{32} + w_{231}*w_{33} )  + n_{1_2}* ( w_{212}* w_{31} + w_{222}* w_{32} + w_{232}*w_{33}) +      n_{1_3}* (w_{213}* w_{31} + w_{223}* w_{32} + w_{233}*w_{33} )  +  ( b_{21}* w_{31} + b_{22}* w_{32} + b_{23}*w_{33} + b_{31}) = n_{output}
# $$
#
# AZ WC -> compact
#
#
# $$
# w_{211}* w_{31} + w_{221}* w_{32} + w_{231}*w_{33} = Wc1
#
# w_{212}* w_{31} + w_{222}* w_{32} + w_{232}*w_{33} = Wc2
#
#
# w_{213}* w_{31} + w_{223}* w_{32} + w_{233}*w_{33} = Wc3
#
# b_{21}* w_{31} + b_{22}* w_{32} + b_{23}*w_{33} + b_{31} = Bc1
#
#
# $$
#
# Pas mishe :
# $$
# n_{1_1} * (Wc1 )  + n_{1_2}* (Wc2) +      n_{1_3}* (Wc3 )  + ( Bc1) = n_{output}
# $$
#
# hala miam n{1_1}
#
# $$
# X_{1}*w_{11}+X_{2}*w_{12} +X_{3}*w_{13} +b_{11} = n_{1_1}
# $$
#
# $$
# X_{1}*w_{21}+X_{2}*w_{22} +X_{3}*w_{23} +b_{12} = n_{1_2}
# $$
# $$
# X_{1}*w_{31}+X_{2}*w_{32} +X_{3}*w_{33} +b_{13} = n_{1_3}
# $$
#
#
# Next :
#
#
# $$
# (X_{1}*w_{11}+X_{2}*w_{12} +X_{3}*w_{13} +b_{11}) * (Wc1 )  + (X_{1}*w_{21}+X_{2}*w_{22} +X_{3}*w_{23} +b_{12} )* (Wc2) +  (X_{1}*w_{31}+X_{2}*w_{32} +X_{3}*w_{33} +b_{13}* (Wc3 )  + ( Bc1) = n_{output}
# $$
#
#
# Weight haor bbrim too
#
# $$
# X_{1}*w_{11}*Wc1  +X_{2}*w_{12}*Wc1 +X_{3}*w_{13}*Wc1 +b_{11}*Wc1    + X_{1}*w_{21}*Wc2 +X_{2}*w_{22} *Wc2  +X_{3}*w_{23}*Wc2 +b_{12}*Wc2 +  X_{1}*w_{31}*Wc3 +X_{2}*w_{32}*Wc3 +X_{3}*_{w33}*Wc3 +b_{13}*Wc3 + ( Bc1) = n_{output}
# $$
#
#
# Next :
#
# $$
# X_{1}*(w_{11}*Wc1 + w_{21}*Wc2  + w_{31}*Wc3 )  +X_{2}* ( w_{12}*Wc1 + w_{22} *Wc2  +w_{32}*Wc3  ) + X_{3}*( w_{13}*Wc1 +w_{23}*Wc2 + w_{33}*Wc3 )  + ( b_{11}*Wc1  + +b_{12}*Wc2 +b_{13}*Wc3 + Bc1) = n_{output}
# $$
#
# Mitonim biaym W very compacty ro besazim yani
# Wvc -> W very compact
#
# $$
# w_{11}*Wc1 + w_{21}*Wc2  + w_{31}*Wc3 = W_{vc1}
# w_{12}*Wc1 + w_{22} *Wc2  +w_{32}*Wc3  = W_{vc2}
# w_{13}*Wc1 +w_{23}*Wc2 + w_{33}*Wc3  = W_{vc3}
# b_{11}*Wc1  + +b_{12}*Wc2 +b_{13}*Wc3 + Bc1 = B_{vc}
#
# $$
#
#
# Dar akhar :
#
# $$
# X_{1}*W_{vc1}  +X_{2}*  W_{vc2} + X_{3}*W_{vc3}  + B_{vc} = n_{output}
# $$
#
#
# 3 layers bood --> n_oiutput = weigth * X ha + Bias --> khob inke hamon linear --> yani 100 laye ham bezarid ba weight haye motefavet --> yeklayer --> layer ha linear bashand

# %% [markdown]
# N_{1_1} = F(W* X + B)
#
#
# Khorojie neuron bere dakhele yek function , mnon linear kone b do dalil
#
# 1- Age non linear nakone, deep network nadarid, 100 laye ba 1 laye yeksan mishe
#
# 2- Rabeteye beyne vorodi va khoorji khati nist, complex , non linear , activation
#
#
# khorojie neuron $\sum{W*x+B}$ mire zire yek function va khoroji
#
#
#
# ### Sigmoid
#
# formula is $$\sigma{x} = \frac{1}{1+e^{-x}}$$
#
# Khoroji beyne 0 ta 1 mide. in yani shoma khorojie haye neuronet normalzie
#
# ![sigmoid_plot](https://upload.wikimedia.org/wikipedia/commons/8/88/Logistic-curve.svg?utm_source=en.wikipedia.org&utm_campaign=index&utm_content=original)
#
#
# dakhel hidden layer ya binary clasfication (output) ,
#
#
# Weight ro update koni --> $$W_{new} = W_{old} - \frac{ro Loss}{ro Weight}$$
#
# mostaghim hesab nemishe bayad
#
# $$\frac{ro Loss}{ro W} = \frac{ro Loss}{ro Z} * \frac{ro Z}{ro W}$$
#
# $$Z = f(w*x + b)$$
#
#
# F() ke activatuon fucntion hast mohstagh pazir bashad.

# %% [markdown]
# #### tanh
#
# Hamoon sigmoid has ba in tafavot k khorojish beyne -1 ta +1 .
#
# formual $$tanh(x)$$
#
#
# ![tanh_plot](https://media.geeksforgeeks.org/wp-content/uploads/20250214171817652462/tanh.png)

# %% [markdown]
# #### Problem of Sigmoid and Tanh
#
# baraye x haee ( khorojie neuorn) ke kh bozorg hastan ya kh kochik hastan --> moshtagh 0 mishe . yani Ro Z / Ro weitgh sefr mishe , ro Loss/ Ro w sefr mishe
#
# ghanone update shoma chi bood?
#
# $$W_{new} = W_{old} - Learning_rate * \frac{ro loss}{ro W}$$
#
# agar in msohtagh sefr beshe ( vaghty kh khorojiha ya bozorg hastan ya kochik hastan)
#
#
# $$W_{new} = W_{old} $$
#
# update ndri , yani learning stop mishe --> ** Vanishing Gradient**

# %% [markdown]
# ### ReLu
#
# in default activation toye ketabkhone ha hast
#
# formula $$f(x) = max(0,x)$$
#
# age x et bozorgtar az 0 bashe (postive ) --> khodesh
#
# age 0 ya kochiktr bashe --> 0
#
#
# ![relu_plot](https://machinelearningmastery.com/wp-content/uploads/2018/10/Line-Plot-of-Rectified-Linear-Activation-for-Negative-and-Positive-Inputs.png)

# %% [markdown]
# Choon moshkele vanishing gradient ro nadarim -> azin tooye hidden layer size ha estefade msihavad.
#
# Ama khodesh yek moshkel dare, agar yek neuron hamsihe manfi bashe -> na tanha khoroji 0 hast , gradient ham 0 hast , oon neuron mimire -> **dead neurons** va neuron haee k 0 ya manfi bashan , inja mimiran --> oon ghesmat az shabake yad nmigirre , morde hesba. selol haye khaskestari magzh , neuronha mimiran .
#
# vase hamin omdn rahe hal --> goftn biaym tooye x<0 shod --> 0 e motlagh nashe va hata moshatghesham 0 nashe
#
# #### Leaky Relu
# ![leaky_relu](https://notesbylex.com/_media/leaky-relu-activate-examples.png)

# %% [markdown]
# #### Elu
# exponential, smoohther and better than leaky relu
#
# for negative we have $/alpha (e**x - 1)$
#
# zire 0 --> exponential function
#
# #### Gelu
# in kheyli moheme , transformers ha , nmesle BERT , GPT , Vision an d....
#
#
# ![different_relu](https://www.digitalocean.com/cdn-cgi/image/quality=75/https://www.digitalocean.com/api/static-content/v1/images?src=https%3A%2F%2Fdoimages.nyc3.cdn.digitaloceanspaces.com%2F010AI-ML%2F2025%2FShaoni%2FAdrien%2F9-oct%2FImage_4.png&raw=1)

# %% [markdown]
# #### Softmax
#
# ghablia too hidden layerz estefade mishod, in yeki tooye output layers. in yek activation function sarasari, kole laye ro posheshmide, kole neuron haro mibine --> 0 - 1 migire
#
#
# 100 , 60 , 40 bashe
#
#
# khoroji inaro --> hamashin jameshon beshe 0 - 1
#
# 200 --> 100/200 --> 0.50  ,
#
# 60/200 --> 0.30
#
# 40/200 --> 0.2
#
# [0.5 , 0.3 , 0.2]
#
# z --> f--> f(z)
#
# 100 --> f(soft max)--> 0.5
#
#
# output lyaer baraye classification -> softmax estefade mishe

# %% [markdown]
# ----------
# ----------
# ----------
# ----------
# # Batch and Epoch (iterations)
#
# ## Batch gradient descent
#
# vaghty migi yek data mizarim tooye random netowrk -> output --> loss hesab miknim, bar oon asas, update mikonim kole wieght , yek data --> yek radif az kole dataset
#
# man migm na mitoni kole batch kole dataseteto bede , hame beran oon to (network) --> Y=[y1,y2,y3,....yn] bad in pishbii ba vagheiat menha koni --> Loss1,loss2,loss3,... --> gradient hamashono (average) brordari -> weight hato update koni --> awli atrin
#
# 1 milion data --> RAM ha mitone anjam bede, zamaaneshoo ( zaman bar bashe)
#
# whole dataseteto in kar kone --> one-batch gradient descent ->behtrin --> daghigh tarine --> shodani nist , computational limitation (mahdoodiate mohasebati)
#
#
#
# ### Stochastic gradient descent
#
# har dae yek dataye random bede, yani yek datbedde update kone w0 -->w1 , dataye badi, databye badi ..... beresi b akhar --> sari msihe m, fgth 1 data dar har update dre train . --> 1 million data, b eaye done donash weigh update -_> oon ziad , kam mishe ziad mishe . tedade bsihatri dsde bbine
#
#
# ### Mini batch gradient descent
#
# kole batch (kole dataset) --> tabdil kon b mini bathc ha (16  , 32, 64, 128 ) --> nesbat b ramet . too har dafe (iteration) bia b tedad batch size (32) data ro varede network W0,B0 (random) --> baray ehame 32 ta $\hat{Y}$ ba vagheiat --> 32 ta loss darim, weight ha bar asase in loss ha updat emishge.  W1,B1 feed forward + backpropagation --> update on loss on 32 dataset (iteration)
#
# miri batch badi -> W2,B2 ,...--> Wn , Bn --> Zamani k kole dataset ro did (w0,b0--->didane kole dataset (batch batch) --> W , B) epoch
#
# va shoma training --> dar chand epoch anjam mishe, 40 ta epoch anajm bshe
#
#
#
# 160 ta data darim , batch size = 16 ta
#
#
# 10 ta batch ,.
#
#
# random W0,B0 darim, 16 ta data (batch1) --> feed forward (pishbini) --> loss hesab mikone -> gradient --> udpate --> weight w1,b1 (iteration)
#
# 10 ta iteration _. 160 ta dataro bbine --> Wjadid, Bjadid -->  1 Epoch
#
# 30 ta epoch
#
# W0---->W30
#
# w0 --> W1
#
# w0 --> W0_iteration0 -->W0_iteration1 -->w0_iteration2-->>..............iterations(mini batchg) ---> W1 {w epoch 1}
#
#
#
# ----------
# ----------
# ----------
# ----------
# # Optimizer
#
# yek algotihtmi hast k bar asase loss gradient descent, update ro anajm mide
#
#
#
# #### Simple Optimzier : Gradient descent
#
# $$W_{new} = W_{old} - \frac{ro Loss}{ro W}$$
#
# in optimzier anjam mide,
#
#
# moshkel ine ke kh vaghta ma dar lcoal minima gir mioftim.
#
# Hadafe asli: Betavanim Weighti ro hesab konim k minimum tarin loss ro dashte bashim $\hat{y} - y$ pishbinimon kh daghigh she.
#
# ma weitgh haro hey update mikonim ba oon formule (dar jahant gradient descent) k b bhtrin loss bresim.
#
#
# ![local_minima](https://i2tutorials.com/wp-content/media/2019/09/Neural-network-33-i2tutorials.png)

# %% [markdown]
# ------
# #### SGD + Momentum
#
# Yekseri lcoal minima ha kochikan , zeshte k inahme netwrok benevisim toosh gir kone, mesle toop bebin, toop vaghty maid paeein , ag dare ba sorate khob mir epaeein, hey shibe hey b samte paeine, sorat bde behesh , bgo boro rahta bash, ag na , didim in dare chapo rast misghe, aghab miad jolo  , inja shib nist . sorat nade
#
# vaghty sorat migire, ag jaye kochiki bashe --> in toopp azon chale miad biron.
#
# Learnign rate ma dg inja yejoraei sabet nist.
#
# pas in shetabe fararish mide az lcoal minima. bayad dakhele update formual yek formu,li bzarim k velocity dashte (sorat) shetab bedim --> Momentum
#
#
# pas yek history az gradient haye ghabli ro dare, bar asase oona shetab migire., ag hamashon are - - - - na tanha edam emide, balke shedato bsihtr mikone .
#
#
# ```python
# torch.optim.SGD(
#     model.parameters(),
#     lr=0.01,
#     momentum=0.9
# )
#
# ```
#
# ------
# #### Adagrad
#
# learnign rate -> cheghadr udpate kone weight ro . yedone kafie, ma baray ehame weight ha ahstan , aya doroste ke ,
#
# yani ma ag weight neuron 8 , neuron 2 --> learning rate = 0.0001 , neuron 8 niaz bashe learning rate bszorg bshe, kochik bashe .
#
# dynamic learning rate dashet bashim --> AdaGrad --> algorithm .
#
# mitoni optimzier sgd , sgd momentum ya adagrad bzari -> learning rate bar asase -> Gradient harche bishtr bshe , leasrning rate ro kam taer kone
#
# Gradient desxcen harchi bzoorgtr mishe --> learning rate kam mishe, pas dg harkeat nmikone,-=> training stop.
#
#
# moshkel ro darim
#
#
#
# ------
# #### RMSprop
# in md gof k bejaye inke tamame history ro (tamame gradient haye ghabli ro ) zakhir ekoni, k gradiente kolet inghd bozorg nbeshe, learning rate majbor she kh kochik bshe, az ye jaei b bad gradient haye ghabl ro hazzf kon, 10 ta bishtr man gradient acccumulate nmikone 9zakhire nmikom
#
# forgetting mechanism (mechanism faramsoho) jologiri kone az bozorg shdoane bisha z hade gradient
#
#
#
#
# ------
# #### Adam
# adaptive moment estimation
#
# combination momentum (Sheta mie locsla) + RMSProp (learnign rate sabet) in 2014 -->
#
# most popolar , verty fast conevrag , less tuning.
#
#
# SGD + momentun ya adam
#
#
# ------
# #### AdamW
# adam yek msohekli decay --> nasht --> miaym dakhelesh penaltize mionim big weight s--> dakhele lass nmizrim b sooe mirim , mdoelemon nare weigth haye bzoorg entkehab kone barsay correct psihbini  kardn
#
# loss hjam bayad psihbinish nazdik b vagheiat bashe, ham inkaro ba weight haye kam anajm bde
#
# nopwdays trasnformer model , BERT, Gpt , visiion --> adamW

# %% [markdown]
# -----------
# -----------
#
# # Coding Neural network
#
# next file
