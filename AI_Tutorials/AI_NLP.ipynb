# %% [markdown]
# # AI_NLP
#
# NLP --> Natursal Language Processing --> Processse zabane tabiei
#
# Sequential data --> TEXT --> numbers mishwe
#
#
#
#
# Neural networks , -> Numbers yad migirim? chon vorodiue hamashon adad hast .
#
#
# hamchnin--> engineering, masael -> javab mide, by default ma number darim
#
# 3 halat mohem --> adad nadarid
#
# 1 - Ax , Video --> Computer vision (binaei machine) --> pixel -->  R matrix,  G Matrix ,  B Matrix
#
# matrix --> chandin pixel , har pixel yek adad dade shode
#
#
# flatten , CNN (kernel) ,....
#
#
# ghabl az axe baid -> keifiat paein, edge migrdim.
#
# preprocessing ghabl az ine ke b NN (openCV)
#
# tasvir --> numbers --> NEURAL NETYWORK
#
#
#
# 2 - Audio darim --> signal processing
#
#
# signal hamon b ravesh haye mokhtalef  tabdil mikonim b numbers --> sequence az numbers
#
# ketabkhone haye khdoesho dre
#
# seda --> numbers --> Neural Network
#
#
#
# 3 - Natural Language processing --> TEXT
#
# text --> numberds ---> neural network, RNN, LSTM , Seq2Seq models, transfomers ,....
#
#
# ```bsh
# Raw Text
#   |
# Tokenization
#   |
# Tokens
#   |
# vocabulary
#   |
# toekn IDs
#   |
# Numerical Represnetation
#   |
# Neural networks
#
#
#
# ```
#
#
# kole datasetemon hast
#
# ```bsh
# texts = [
#     "I love AI",
#     "I love Python",
#     "Python is powerful"
# ]
#
# ```
#
# neiural network, model(text)  --> z =  w*x + b  , output = f(x) . x agar adad nabaashe, weigth * ...
#
# convert text to numbrs
#
#
# ## Tokenization
#
# Token --> yani bia oon jomlato tabdil komn b ghesmat haye kochik tar
#
# masalan
#
# ```bsh
# ["I", "love", "artificial", "intelligence"]
# ```
#
# tokenization
#
# ```bsh
# Text
#  ↓
# Tokenizer
#  ↓
# Tokens
# ```
#
#
# sade tarin tokenization

# %%
text = 'i love artificial intelligence'

tokens = text.split() #''

print(tokens)
# Out:
# ['i', 'love', 'artificial', 'intelligence']

# %% [markdown]
# Chdnin no tokenization darim. AI. AI , AI? se ta tafavot daran. numerical representation ( namayeshe adadi)
#
# - Word level --> yek word --> yek token
# - character level --> har character yek token --> harf yek token --> bozorgi
# - Subword- level --> modern models , unbelivable --> 1 word -->
# ```bsh
# ['un','beliv','able']
# ```
# new words ha ham beshnase
#
#
# Inaro ma import mikonim , va har modeli , tokenizater khodsho dre
#
#
# hugging face --> GPT , yek modeel khaso mairim --> bar ase -> token shode . tokenizer khodesho dare

# %% [markdown]
# ## What i svocabulary
#
# fek kon yek dataset
#
# ```bsh
# I love AI
# I love Python
# Python is powerful
# ```
#
#
# hala toknization
# ```bsh
# ["I", "love", "AI"]
# ["I", "love", "Python"]
# ["Python", "is", "powerful"]
# ```
#
# miaym fhjt token haye unique (yekta) kenare ham mziarim
#
# ```bsh
# I
# love
# AI
# Python
# is
# powerful
# ```
#
#
#
# Be harkodomeshon --> yek token ID midahim
#
# ```bsh
#
# I        → 0
# love     → 1
# AI       → 2
# Python   → 3
# is       → 4
# powerful → 5
# ```
#
#
# pipeline
# ```bsh
# "I love AI"
#
#       ↓ Tokenization
#
# ["I", "love", "AI"]
#
#       ↓ Vocabulary Lookup
#
# [0, 1, 2]
# ```
#
#
#
# 0 1 2 --> numerical represnetation. I ->0 , love ->1 AI-->2 injori nista
#
#
#
# UNK --> token id --> pad -> 0 , UNK --> 1
#
# ```bsh
# <PAD>      → 0
# <UNK>      → 1
# i          → 2
# love       → 3
# ai         → 4
# python     → 5
# is         → 6
# powerful   → 7
#
# ```
#
#
# i love ai --> [2,3,4]
#
#
# ina token id hastan --> id dadi beheshon --> manage oon toye python
#
#
# Token id --> Embedding vectors , numebr
#
# ## Embedding numbers
# text --> tokens --> token token id --> har kodom --> numerical representation
#
#
# hamaro --> tabdl beyek vector -->
# good = [10,20]
#
# great = [40,35]
#
#
# good = [10,56,........,50]
#
# - bayad similar words nazdik b ham bashan
# - aya baraye har kalame bayd yek vector bekar bod ? nemishe dota seta bord . great to yek jomle mani , mani
#
# this is too great . positive
# my phone is break , great !  negative
#
# context ham negah konim
#
#
# ravehs haye gahdimi
#
# - one hot encoding
# - bag of words
# - N-grams
#
#
# ravehs haye ghadimi bode
#
#
# -----------
# # Embedding mdoels
#
#
# baraye har token , bia yek vector besaz
#
# ```bsh
# cat →
#
# [0.82, 0.31, -0.52]
#
#
# dog →
#
# [0.79, 0.35, -0.48]
#
#
# car →
#
# [-0.12, 0.91, 0.73]
# ```
#
#
# vocabulary --> tamame dataset
# ```bsh
# ID    Token      Embedding
#
# 0     <PAD>      [0.0,  0.0,  0.0]
# 1     cat        [0.8,  0.3, -0.5]
# 2     dog        [0.7,  0.4, -0.4]
# 3     car        [-0.2, 0.9,  0.7]
# 4     apple      [0.1, -0.8,  0.2]
# ```
#
#
#
# Vaghty yek text miad barat --> neural newtork . aval -_> tokenization anjam midi -> token (sub word) -->(tokenn id) -->ovcabualry --> model() --> embedding vectors
#
# shoma oon text --> b ezaye token hash chandin emedding vector
#
#
# I love cat --> [i , love , cat] --> [ [0.1,  0.2,  0.3] ,[0.1, -0.8,  0.2] ,  [0.8,  0.3, -0.5] ] --> neural network
#
#
# ## Embeding mdoels --> modeli k emebding mikone
#
# token midi behesh -> tabdil kone be yek vectore mana dar
#
#
# do rah vojod dare baraye inke
#
#
#
# ### Approache 1 -> khodet ino besazi
#
# sentimetn analysis
#
# texts --> tokenizer --> token ID --> embedding --> neural network --> positive/negative
#
#
# ```python
# model = tf.keras.Sequential([
#
#     tf.keras.layers.Embedding(
#         input_dim=10000,  #har adad ro ba 1000 numebr neshon midam    cat=[2233,32333,322233,32323,323233232]
#         output_dim=64
#     ),
#
#     tf.keras.layers.GlobalAveragePooling1D(),
#
#     tf.keras.layers.Dense(
#         32,
#         activation="relu"
#     ),
#
#     tf.keras.layers.Dense(
#         1,
#         activation="sigmoid"
#     )
# ])
#
# #output yek nueorn hast k yek chizi beyne 0 ta 1 behet mide
# ```
#
# vaghty rooye datat train --> embedding khodesh yad migire --> embeding laywer ha -_> modeli msihe
#
# #har text --> numbers --> khodesh yad migire
#
#
# ### Approache 2 -> kpre trained hga estefade koni --> koli modele embedding dar
#
# practcial --> thesis --> bank ha datahaye bank ,--> sensetive hasas
#
# hamaro GPT vasl koni, dade haye dakhele keshvbar --> federated learning (FL)
#
# gpt , claud ,.. -> model haye mebeddinge motefavet daran --> ma yek model darim
#
# API -_> texto befres bar ama --> bvectoresh pas midim ..
#
#
# agar embedingi k khoddet msiazi , rooye dataye kami bashe, layere kami , compelx nabashe --> adadi k mide baraye represent ahr tokenet bi mani baghi mimanad
#
# after training of embedding model
#
# cat = [10 , 40, 60] <br>
# dog = [11 , 42 , 64]
#
#
# ama shoam mibini  <br>
# cat = [10 , 40, 60] <br>
# dog = [-1000 , -3232 , +32333w]
#
# neurla network text --> token -_> hamin chiza --> midi , asan dakheel in adad hich mani e nis , koli adade random b neural network bedi begi hala bia sentiment naalysis kon
#
# https://costgoat.com/pricing/openai-embeddings
#
# embeding mdoel -> text  --> text (tokenize mikoni) -> token
#
# token --> api() --> modele (servere) --> embedding vector (adad)
#
# dimension 1536--> har token ro ba 1536 asdad namayesh mide
#
#
#
# ```bsh
# Text Embedding 3 Small
# Smallest & Cheapest
#
# Dimensions -->  1,536
# Good
# $0.02
#
#
#
# Text Embedding 3 Large
# Highest Quality
#
# Dimensions -->  3,072
# Best
# $0.13
#
# ```
#
# Text Embedding 3 Large-->  janaury 24 , 3072 dimension .
#
#
# 1 ta 3 trillion tokens
#
#
#
# ```bsh
#              "I love deep learning"
#                        │
#                        ▼
#                   Tokenization
#                        │
#                        ▼
#         ["I", "love", "deep", "learning"]
#                        │
#                        ▼
#                    Token IDs
#                        │
#                        ▼
#               [15, 83, 219, 41]
#                        │
#                        ▼
#                Embedding Matrix
#                        │
#                        ▼
#      ┌─────────────────────────────────┐
#      │ I        → [ ... vector ... ]   │
#      │ love     → [ ... vector ... ]   │
#      │ deep     → [ ... vector ... ]   │
#      │ learning → [ ... vector ... ]   │
#      └─────────────────────────────────┘
#                        │
#                        ▼
#                 Neural Network
#                  /           \
#                RNN       Transformer
#
# ```
#
#
# ```bsh
# pip install gensim
# ```
#
# ```python
# print(list(api.info()["models"].keys()))
# ```
#
# ```python
# import gensim.downloader as api
#
# model = api.load("glove-wiki-gigaword-100")
#
# v = model["king"]
#
# print(v)
# print(v.shape)
#
#
# #[0.12, -0.43, 0.81, ... ]
# #(100,)
# ```
#
# ```python
# model = api.load("word2vec-google-news-300")
# model["computer"]
# ```
#
#
#
#
# embedding rto dar ekhtiar e ma mizaran, ama be rasti chegone embedding models mitavanad text ra be vector tabdil konad?
#
#
# ------------
#
# # Embedding models
#
# trol 2 is great
# gymakta is great
#
#
# trol2  <br>
# is <br>
# great <br>
# gymakta <br>
#
#
# neural netwok --> 4 ta input dare
#
#
# input 1 0 0 0
#
#
#
#
# ![word1](word1.png)

# %% [markdown]
# ![word2](word2.png)

# %% [markdown]
# agar vorodie man , masalan troll 2 --> neural network --> vorodi man trol2 --> 4 ta input , input`1 input2 , input3 , input4 --> [1 ,0,0,0]  trol2 .... -> manzorma kalameye troll2
#
# mire too netwiorjk --> activatuon , weights ,...._.sum , softmax --> teroll2 , is , grreat, gymkata (4 ta output neuron) --> darsad mide
#
#
# tooye jomleye e, vorodimo k midam , khorojio pishbini koni . edameye one
#
# trol2 --> is
#
#
# hadafr man az trainign in hast.
#
# ![word3](word3.png)

# %% [markdown]
# random numebrs --> trol2 --> ta hame wiehth ha adjust beshan --> yani training ataset --> in hey vorodi mide . 4 ta kalame, 4 ta khoroji
#
# inja aavale kar 2 t aactivation function. har vorodi man mitone 2 ta weight dashte bashe . bad z backpropagation , neural network ,... --> resutla khob abshe--> weigtham optimzie shode bashe
#
# hala in weigth haye layer 1 --> vector
#
# ![word4](word4.png)

# %% [markdown]
# bejaye trol2 man mitavanam az in 0.38 , 0.42 estefade kojam. trol2 --> [0.38,0.42] . omadam ba vector yek kalame ro namayesh dadam
#
#
# trol2 , gymkata kenare ham bioftan --> khob train shdoe .
#
#
#
#
#
# # Word2Vect
#
# word --> vector
#
# az do ravehs estegfade krd
#
#
# - continious bag of words
#
# bia beja inkkara, negah k b doro atrafe yek jomle, va middl ero pishbini kon
#
# ![word7](word7.png)
#
#
# - skip gram
#
# middle ro bebin va doro var ro pishbini kon
# ![word8](word8.png)

# %% [markdown]
# magahlee word2vec --> 3 million kalame (token) , weights --> 100 ta dimension vector --> 600 million weight dshtim va dar nahayt yek modeli sakhte shdo, k rooye 3 million kalame dakhele jomel (wikipedia)
#
#
# omade conetxt ro fhmde--> modeli darim --> words (token)--> vared mishe  --> yek vector mide -->
#
#
# trol2 --> [12,23,-34,23.........(*100)]

# %% [markdown]
# More on **Spicy** and **nltk** and ....
