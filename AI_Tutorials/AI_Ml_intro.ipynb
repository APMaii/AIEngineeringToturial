# %% [markdown]
# # Ai ML Introduction
#
#
#
# Artificial intelligence ( Hooshe masnoei) yani inke machine (system ) betavanad mananade yek ensan yek data begirad va az rooyash yad begirad va mantegh kasb konad, va bar asase on mantegh tasmim (amal konad) begirad.
#
# AI chand nasl dasht, nasle 1 hamoon automation bood (If , else ,..) pas in yad nemigereft , balke ba hard code (koli if else ,toolani, zaman bar) bayad hamechiz ro dar nazar migrfti , automation anjam bedi .
#
#
# Nasle 2 (Second geenration) --> Biaym vaghean be manaye kalame AI ro besazim, biaem kari konim k Machine (Transistor, yek ghate silicon --> Jamed ) --> In yad begire ( be soorate amari )
#
# Dar hiteye AI , Machine learning (ML) 70,80% AI ro poshesh mide , symbolic ai , optimziation , rule-based ,.... .
#
#
# Machine learning be soorate koli :
#
# 1- Supervised  ML <br>
# 2- Unsupervised ML  <br>
# 3- Reinforcement Learning (RL)  <br>
# 4- Deep Learning (DL)  <br>
#
# Kole donyaro ma mitavanim be yek masale ye **input-output** tabdil konim .
#
# Mesal:
# - Ax haye pezeshki (voroodi) --> Khoroji (tashkhis) <br>
# - azmayesh haye material , mechanic (vorodi) --> khoroji (arzyabi) <br>
# - ax haye khiaban ha ( vorodi) --> khoroji (tashkhis machine haye khod ran ,..) <br>
# - soal porsidan az gpt (vorodi) --> khoroji (javabe khode gpt) <br>
#
# bar in asas ma miaeem k bbinim masalamon ro ba kodom yek az approach haye ML anjam bedim <br>
#
#
# --------------
#
# Age Datamoon Amade bashe ... --> (1) , (2) , (4) <br>
#
# agar datamoon sizesh kh ziad bashe (100000 , milllion, billion ,,....) --> (Deep learning)
#
#
# Agar datamoon andazash ok bashe <...  (ML)
#
# migim aya vorodi darim va khoroji ham darim ?
#
# Age na nadarim --> Unsupervised learning  <br>
# Clustering  , .... , tedad data baalst, label zadan sakhte, hazine bare , zaman bare, nashodanbi ,..
#
#
#
#
#
# Age are --> Supervised learning <br>
# yani ham datamoon maghole andazash, ham vorodi darim (x) , ham khoroji darim(y) <br>
# Khode supervsied b 2 ghesmat taghsim mishe bar asase khoroji :
#
# - age khoroji gosaste bashe , chanta ee , 2 tae, 3 taee, sag va gorbe , badkhim khoshkhim , awli , kh khoobm, khoob , bad , ... --> Supervised Classification
#
#
# - age khoroji peyvaste bashe, masalan yek adade, yek range dare, ashar mitone begir , .. vazn , estehkam , moalefeye yek azayesh saratan , .. --> Supervised Regression
#
#
#
#
#
#
#
#
# --------------
# Age data nadashte bashim, bekhahim too khod emohit yad begire, data be soorate peyvaste done done varede systememon beshe RL (4) <br>

# %% [markdown]
# --------
# # Statistical Regression
#
# Ma chizi dairm bename supervised regression. aval ye hite ee bename statistical regresion ro yad bedim , badan varede supervised regreession.
#
#
# zamani k ma vorodi va khoroji darim dar yek data . agar vorodi va khorojie ma baham ertebat dashte bashan va khorojie ma peyvaste bashe, va yek rabete e beyne in do bashad, agar ma mikhahim in rabete ro bedast biavarim , regresion baayd begirim.
#
#
# Dama dar yek farayand kamo ziad mishe, dar damahaaye mokhtalef, ma estehkam haye mokhtalef darim.
#
# Dar donyaye vagehiat , dar zire pardeye tabiat : <br>
# Estehkam = 10*dama + 20
#
# dama=40 -->  400 + 20  --> 420 <br>
# dama = 60 --> 600 + 20 --> 620 <br>
#
# in rabete ro ma nemidanim . jaee naneveshte k bedonim . balke joloye ma fght yek dastgah hast k mitavanim berim va damaro taghir bedim <br>
#
#
# agha bia berim dama ro az 0 , 1 , 2, 3, 4, 5, .... 10000 <br>
# too har kodom estyehkam ro hesab kon, khatet dar miad <br>
#
# hamchin chizi hazine bar va zaman bare .
#
# Dama masalan rangsh hast 0 - 100 . speed (0-100) , (0-100) --> 100x100x100 = 1000000 <br>
# anjame va sakht har 3d printing --> 1 saat --> 2 ,3 saaat cooling, 1 saat colling ,4 <br> 4 million saat --> 456 sal niaz darid ta beshe kole process ro anjam bdid taze inja fght 3 ta variable hast va range 0 ta 100 . yani dar donyaye vagehei, hata tedad variable ha bsihtar, range ham bishtar hast. taze hazine ro ham hesab nakardam <br>
#
# Pas ma datamoon mahdodtare, ma ba megdhari data mikhahim oon rabete bala ro bedast biarim.
#
#
# dama   estehkam <br>
# 10      105  <br>
# 20      210  <br>
# 30      290  <br>
# 40      405  <br>
# 50      487  <br>

# %%
import numpy as np

temperature = np.array([10,20,30,40,50])
estehkam = np.array([105,210,290,405,487])

import matplotlib.pyplot as plt

plt.scatter(temperature, estehkam)
plt.xlabel('Temperature')
plt.ylabel('Estehkam')
plt.title('Estehkam vs Temperature')
plt.show()

# %% [markdown]
# ## Tarigheye kare regressione Khati
#
# farz mikonad rabte ee beyne x va y vojod darad, va in rabete khati mibashad. <br>
# mige ke ba y = a*x + b , ba taghire a (shib), taghire b (arz az mabda) mitavanid chandind khat rasm konid, doone doone khat rasm konid, bebini b in noghte ha cheghdr nazdike (Khataye khat va noghte ha , be tavane 2 mikonim MSE , ,....), loss function.
#
# baraye har khat yek loss value , paeen tarin loss value ? yani inke oon khat nazdik tarine b noghte ha , yani azashoon obor krde holo hosh va ,,.... <br>
#
# va oon khate yek a va b ee darad , ooon a va b ? --> hamoon a , b k moadele ee k dar nature hast <br>
#
# hala man estehkam = 10* temp + 20 , pas dg mitonam baraye tamame temperature hayte donya azin moadele estefade konm bedone naiz b azmayesh .
#
# 1- Phase modeling ( k besoorate amari model krdm) <br>
# 2- Inference pahse (estefade) --> daram vorodi midam va khoroji pishbini mikone <br>

# %%
import numpy as np
import matplotlib.pyplot as plt

temperature = np.array([10,20,30,40,50])
estehkam = np.array([105,210,290,405,487])


def linear_regression(x,y):
    best_loss = 10000000000000000000
    best_a = 0
    best_b = 0

    all_parameters = []

    

    for a in range(100):
        for b in range(100):
            y_pred = a*x + b
            loss = np.mean((y_pred - y )**2)
            if loss < best_loss:
                best_loss = loss
                best_a = a
                best_b = b

                all_parameters.append({'a':a, 'b':b, 'loss':loss})

                plt.scatter(x,y)
                plt.plot(x, y_pred, color='red',label=f'a={a}, b={b}, loss={loss}')
                
                plt.xlabel('Temperature')
                plt.ylabel('Estehkam')
                plt.title('Estehkam vs Temperature')
                plt.xlim(0,70)
                plt.ylim(100,500)
                plt.legend()
                plt.grid()
                plt.show()
            
    return best_a, best_b

#linear_regression(temperature,estehkam)

# %% [markdown]
# Pas statistical regression  , miad yek vorodi khoroji migire, mige man rabeteye beyne in haro yad migiram , mire khat haye motefavet rasm mikone. <br>
#
# mire a va b random entekhab mikone , va shoro mikone , moshtaghe oon loss function bar asase oon parameter migire , be samte negativesh harekat mikone ba yek rate (learning rate) --> Gradient descent <br>
#
# bejaye anke beravie baraye tamame khat ha (a,b) beri done done loss entekhab koni , a 0 b 0,.....100 , a=1 , b=0,...100 , bad negah koni . hamon aval random a=323 , b =32313 va shoro mikone a va b ro dar rastae taghir mdie k gradient loss function ( faseleye beyne khatet va noghat [cheghadr khoob bode model va chdgh nazdik]) negatuve -> be paeen tarin loss function , mesle yek farde nabina k dar kooh harkeat mnikone va fght ba asash mizane be zamin bebine zamin mire paen ya bala (ba shib) ,ag paein bere, ghadam mziane . in asa --> moshtaghe . bejaye inek tamame a, b haye jahan (khat haye jahan) done done bekeshim , mohasebe konim khata (loss funciton) , random yek khat mikshe , hooshmandane tar inkar ra anjam midahad <br>

# %%
#pip install scikit-learn

import numpy as np
import matplotlib.pyplot as plt #kole matplot lib ro nkrdim ,balke pyplot ro import krdim 

#sklearn -> mesle kh az ketabkhane ha sangine,m va doros nist k kolesho import konim 

#import sklearn
#model = sklearn.linear_model.LinearRegression()
#model = sklearn.linear_model.LinearRegression()

#az kole sklearn, foldere linear_model , import kon class LinearRegression
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model = LinearRegression()



from sklearn.linear_model import LinearRegression as LR
model = LR()

#-------------------------------

#LinearRegression --> Az ravehse makoose matrix ha hesab kone
# A * X = Y  --> Y = A -1 * X --> va asan motefavete . 


#SGDRegressor 
# Hamin linear regression (regrasion kahti hast) ba Schotastuc gradient descent , a,b ,..khat b khat ,....

#yek ravehse amari hast kl parametr haye dakheli dre, taghireshon mide, va loss function ( faseleye oon khat , noghate vageh ei hesab mikone)


from sklearn.linear_model import SGDRegressor

model = SGDRegressor() #in yek class hast 

#settingesho dakhele khodesh moarefi mikoni msiazi

model = SGDRegressor(loss = 'squared_error',learning_rate='constant',eta0=0.0001 , max_iter=10000,random_state=42)

#chijori loss fucntion hesab konam ? boro square error -> be tavane do
#Gradient descent, vaghty mosjtagh migiram, a , b rotaghir bdm , learning rate  , ziad 

# a = a0 + alpha * mohstaghe loss / a 
#alpha --> learning rate

#Agar learnign rate ziad bashad  --> azinvar miofte miofti onvar  -->unstable
# Agar kam bashe --> khob peyd amikoni , noghteye minimum --> slow tar hast . arom arom arom paramer ra taghir mdie


#MoDEL -> Object sakhtam --> yekseri method dare


#daklhele sklearn yek folder hast bename linear_Model

#yek file hast bename SGD.py
#dakhele onja in class tarif shode k ma importesh mikonim
class SGDRegressor:

    def __init__(self,loss='squared_error',learning_rate='constant',eta0=0.0001 , max_iter=10000,random_state=42):
        self.loss = loss
        self.learning_rate = learning_rate
        self.eta0 = eta0
        self.max_iter = max_iter
        self.random_state = random_state



    def fit(self,X,y):

        #check mikone age x e shoma ,1D (yek bodi ) error mide , reshape 
        #1d -> 1 soton --> reshape(-1,1)
        #if check --> ValueError: Expected 2D array, got 1D array instead:




        #sgd

        #halgehye for ......

        #for range (0, self.max_iter)
    
        initial_a , intiial_b = _initialize_parameters(X.shape[1]) #a,b,... misaze nesbat b x ha , 

        gradient_a , gradient_b = _gradient(X,y,initial_a,initial_b,self.learning_rate,self.max_iter,self.random_state) #moshtaghe a , b ro migire 

        new_a , new_b = _update_parameters(a,b,gradient_a,gradient_b,self.learning_rate,self.max_iter,self.random_state)

        all_parameters = _loss(new_a,new_b,X,y)

        _record_information(new_a,new_b,loss)

        best_a , best_b , best_loss = _find_best_parameters(self.all_parameters)



        #behtarin a va b ro zajkhire mikone, 

        #a --> coeff --> zarib , shibe
        self.coef_ = best_a

        #b --> intercept --> arz az mabda
        self.intercept_ = best_b



    def predict(self,X):
        #check mikone age x e shoma ,1D (yek bodi ) error mide , reshape 
        #1d -> 1 soton --> reshape(-1,1)
         #if check --> ValueError: Expected 2D array, got 1D array instead:




        #y_pred = a * x + b 
        y_pred = self.coef_ * X + self.intercept_
        return y_pred


    def score(self,X , y):
        #check mikone age x e shoma ,1D (yek bodi ) error mide , reshape 
        #1d -> 1 soton --> reshape(-1,1)
         #if check --> ValueError: Expected 2D array, got 1D array instead:



        y_pred = self.predict(X)
        #faseleye beyne y_pred ba y vaghei ro hesab mikone
        return self._loss(y_pred,y)



    def _initialize_parameters(self,n_features):
        pass


    def _loss(self,y_pred,y_true):
        if self.loss == 'squared_error':
            return np.mean((y_pred - y_true)**2)
        elif self.loss == 'absolute_error':
            return np.mean(np.abs(y_pred - y_true))

    def _gradient(self,x,y,initial_a,initial_b,learning_rate,max_iter,random_state):
        pass

    def _update_parameters(self,a,b,gradient_a,gradient_b,learning_rate,max_iter,random_state):
        pass

    def _find_best_parameters(self,all_parameters):
        pass

    def _record_information(self,new_a,new_b,loss):
        pass

    
    

    
        
        
        

#hamchin classi besorate pishrafte dakhele sklearn vojod darad

from sklearn.linear_model import SGDRegressor

#__init__ --> dkahele init paater ha zakhrie msihe, object az yek class msiazid

model = SGDRegressor(loss = 'squared_error',learning_rate='constant',eta0=0.0001 , max_iter=10000,random_state=42)
  


#avalin tabe , methode model --> fit() --> ba estefade az ravshe gradient peyda mikone
#khorji mide? --> na 

#model.fit(x,y)

#pas agar x
#model.fit(temperature, estehkam) # #if check --> ValueError: Expected 2D array, got 1D array instead:


temperature = temperature.reshape(-1,1) #do bodi koni, 

model.fit(temperature, estehkam)
# Out:
# SGDRegressor(eta0=0.0001, learning_rate='constant', max_iter=10000,
#              random_state=42)

# %%
b = model.intercept_
a = model.coef_

print('a = ',a)
print('b = ',b)


print(f'y = {a} * x + {b}')
# Out:
# a =  [9.88053609]
# b =  [0.28367049]
# y = [9.88053609] * x + [0.28367049]

# %%
print(temperature)
# Out:
# [[10]
#  [20]
#  [30]
#  [40]
#  [50]]

# %%
a * 15 + b
# Out:
# array([148.49171184])

# %%
model.predict(np.array([15]).reshape(-1,1)) #yek adade 15 , numpy array 2 bodi mikhad
# Out:
# array([148.49171184])

# %%
#15,20l,30,40

model.predict(np.array([15,20,30,40]).reshape(-1,1))
# Out:
# array([148.49171184, 197.89439229, 296.69975319, 395.50511409])

# %%
#overall
# ma masale amon ro b x , y tabdil mikonim 

x= temperature
y = estehkam 

#import kardim modelemoon (oon raveshe amari)

from sklearn.linear_model import SGDRegressor
model = SGDRegressor()  #settinge khode ravesh ro set mikonim 

#b ravesh haye dg ee in ro bedast mioare



model.fit(x,y)

model.coef_
model.intercept_

print('a = ',model.coef_)
print('b = ',model.intercept_)
print(f'y = {model.coef_} * x + {model.intercept_}')

new_x = np.array([15]).reshape(-1,1)
y_pred = model.predict(new_x)




#statistcial regression hast , ML , ...
# Out:
# a =  [-1.37129435e+11]
# b =  [2.61582355e+09]
# y = [-1.37129435e+11] * x + [2.61582355e+09]

# %%
import pandas as pd

#q6.a

#Material_Strength_Temperature.xlsx
#excell --> read excel

data = pd.read_excel('/Users/apm/Desktop/Material_Strength_Temperature.xlsx')

data.columns 

#agar x ma do bodi bood chetor?
# Out:
# Index(['Temperature', 'UTS'], dtype='object')

# %%
#Temperature --> dam , UTS --> Ultimate tensile strength (estehkam)

data.head()
# Out:
#    Temperature    UTS
# 0         20.0  590.0
# 1         40.0  578.0
# 2         60.0  571.0
# 3         80.0  560.0
# 4        100.0  552.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  36 non-null     float64
#  1   UTS          36 non-null     float64
# dtypes: float64(2)
# memory usage: 720.0 bytes

# %%
#37 ta data daram, azmayesh najm shode , damahaye mokhtalef , estehkam haye mokhatlef

data.describe()
# Out:
#        Temperature         UTS
# count    36.000000   36.000000
# mean    355.555556  424.722222
# std     244.627349   98.877590
# min    -320.000000  263.000000
# 25%     175.000000  340.750000
# 50%     370.000000  426.500000
# 75%     545.000000  506.000000
# max     740.000000  590.000000

# %%
#1-empty cell 
#2- Type
#3- logical
#4- duplcited


#1-empty cell, type
#taskhis dade mishe
data.info()

#37 ta data darim, 36 ta non null , 1 null 

#column emeprature, column UTS
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  36 non-null     float64
#  1   UTS          36 non-null     float64
# dtypes: float64(2)
# memory usage: 720.0 bytes

# %%
#hazf konm , datam kame , 
#fill , --> fill konid

data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35 entries, 0 to 36
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  35 non-null     float64
#  1   UTS          35 non-null     float64
# dtypes: float64(2)
# memory usage: 840.0 bytes

# %%
#2 --> type
#data['Temperature'] = data['Temperature'].astype(float)


#3-->
#logical
#temeprature nemitone manfi bashad

data.describe()
# Out:
#        Temperature         UTS
# count    35.000000   35.000000
# mean    352.571429  427.857143
# std     247.533038   98.489218
# min    -320.000000  263.000000
# 25%     170.000000  347.000000
# 50%     360.000000  430.000000
# 75%     550.000000  509.000000
# max     740.000000  590.000000

# %%
new_data = data[data['Temperature'] > 0]

# %%
new_data.describe()
# Out:
#        Temperature         UTS
# count    34.000000   34.000000
# mean    372.352941  427.235294
# std     221.401306   99.900574
# min      20.000000  263.000000
# 25%     185.000000  345.000000
# 50%     370.000000  426.500000
# 75%     555.000000  512.000000
# max     740.000000  590.000000

# %%
new_data.duplicated().sum()

#new_data.drop_duplicates(inplace=True)
# Out:
# 0

# %%
new_data.reset_index(drop=True,inplace=True)

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  34 non-null     float64
#  1   UTS          34 non-null     float64
# dtypes: float64(2)
# memory usage: 672.0 bytes

# %%
new_data.columns
# Out:
# Index(['Temperature', 'UTS'], dtype='object')

# %%
new_data.head()
# Out:
#    Temperature    UTS
# 0         20.0  590.0
# 1         40.0  578.0
# 2         60.0  571.0
# 3         80.0  560.0
# 4        100.0  552.0

# %%
new_data.tail()
# Out:
#     Temperature    UTS
# 29        660.0  299.0
# 30        680.0  290.0
# 31        700.0  281.0
# 32        720.0  272.0
# 33        740.0  263.0

# %%
import matplotlib.pyplot as plt

plt.scatter(new_data['Temperature'],new_data['UTS'])
plt.xlabel('Temperature')
plt.ylabel('UTS')
plt.title('Temperature vs UTS')
plt.show()

# %%
#step 0.0 ---> clean sazie data

#step 0.1 --> data ro b x o y tabdil konim

#in doroste
x = new_data['Temperature']
y = new_data['UTS']


#x, y --> tavabe method hjaye sklearn , series, DataFrame
#bayad vojod nadarad, suggestion --> numpy array 

#numpy array 
x = np.array(new_data['Temperature'])
y = np.array(new_data['UTS'])


print(x.ndim) #1  --> 2 d
print(y.ndim) #1


x = x.reshape(-1,1)  #tabdil kon b yek numpy array ( -1 radif, 1 soton)
#bbin sizesh chghdre --> 35 --> (35,1) 35 radif 1 soton


print(x.shape)
# Out:
# 1
# 1
# (34, 1)

# %%
#step 1 
from sklearn.linear_model import SGDRegressor
model = SGDRegressor(loss='squared_error',learning_rate='constant',eta0=0.000001,max_iter=10000,random_state=42)


#step2 --> fit (modeling)
model.fit(x,y)


#miram bbinm

print('a = ',model.coef_)
print('b = ',model.intercept_)

print(f'y = {model.coef_} * x + {model.intercept_}')

#step 3 --> predict
# Out:
# a =  [0.66104156]
# b =  [0.06374848]
# y = [0.66104156] * x + [0.06374848]

# %%
#x
#y

y_pred = model.predict(x)

import matplotlib.pyplot as plt

plt.scatter(x,y,label = 'data')
plt.plot(x,y_pred,label = 'model',color = 'red')
plt.xlabel('Temperature')
plt.ylabel('UTS')
plt.title('Temperature vs UTS')
plt.legend()
plt.show()

# %%
#step 1 
from sklearn.linear_model import SGDRegressor
model = SGDRegressor(loss='squared_error',learning_rate='constant',eta0=0.000001,max_iter=10000,random_state=42)


#step2 --> fit (modeling)
model.fit(x,y)


#miram bbinm

print('a = ',model.coef_)
print('b = ',model.intercept_)

print(f'y = {model.coef_} * x + {model.intercept_}')

#step 3 --> predict
y_pred = model.predict(x)

import matplotlib.pyplot as plt

plt.scatter(x,y,label = 'data')
plt.plot(x,y_pred,label = 'model',color = 'red')
plt.xlabel('Temperature')
plt.ylabel('UTS')
plt.title('Temperature vs UTS')
plt.legend()
plt.show()
# Out:
# a =  [0.66104156]
# b =  [0.06374848]
# y = [0.66104156] * x + [0.06374848]

# %%
#step 1 
from sklearn.linear_model import LinearRegression
model=LinearRegression()

#step2 --> fit (modeling)
model.fit(x,y)


#miram bbinm

print('a = ',model.coef_)
print('b = ',model.intercept_)

print(f'y = {model.coef_} * x + {model.intercept_}')

#step 3 --> predict
y_pred = model.predict(x)

import matplotlib.pyplot as plt

plt.scatter(x,y,label = 'data')
plt.plot(x,y_pred,label = 'model',color = 'red')
plt.xlabel('Temperature')
plt.ylabel('UTS')
plt.title('Temperature vs UTS')
plt.legend()
plt.show()
# Out:
# a =  [-0.45115821]
# b =  595.2253794628247
# y = [-0.45115821] * x + 595.2253794628247

# %%
#step 1 
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()

#step2 --> fit (modeling)
model.fit(x,y)


#miram bbinm

#print('a = ',model.coef_)
#print('b = ',model.intercept_)

#print(f'y = {model.coef_} * x + {model.intercept_}')

#step 3 --> predict
y_pred = model.predict(x)

import matplotlib.pyplot as plt

plt.scatter(x,y,label = 'data')
plt.plot(x,y_pred,label = 'model',color = 'red')
plt.xlabel('Temperature')
plt.ylabel('UTS')
plt.title('Temperature vs UTS')
plt.legend()
plt.show()

# %%
## Q6.B

# T alan ma fght yek x va yek y dashtim
# y = a *x +  b ,......


#agar ma chanta x dahste bashim

# Y = a* x1 + b*x2 + c *x3 + d*x4 + ...... 

#mdoele ma bayad random {a,b,c,d,..} shoro , bere baa hamashon gradient , udpate kone
#Loss funciton b minimum berese -> ta behtarin {a,b} kjat, {a,b,c} safe , {ab,c,d} mokaab , fit mikone




#taxi_fare_dataset.xlsx

#excell -> read excell 
#csv -> read csv

#yekbar impot mishe kafie , man chnbar hey mikonm
import pandas as pd

data = pd.read_excel('/Users/apm/Desktop/taxi_fare_dataset.xlsx')

data.columns
# Out:
# Index(['distance', 'duration', 'traffic', 'speed', 'rain', 'fare'], dtype='object')

# %%
#baraye yek tedadi , safar, masire chghdr bodoe , duration, trafic, speed, rain , fare

data.head()
# Out:
#     distance   duration   traffic      speed      rain        fare
# 0  11.548934  63.438231  0.185133  67.098996  0.261706   84.395736
# 1  28.546072  49.176480  0.541901  62.710007  0.246979  121.224703
# 2  22.093821  29.238430  0.872946  12.820627  0.906255   99.720935
# 3  18.160425  73.613962  0.732225  47.537261  0.249546  117.325635
# 4   5.102550  62.256343  0.806561  51.821518  0.271950   76.033862

# %%
#step 0 --> clean konam data 

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   distance  499 non-null    float64
#  1   duration  499 non-null    float64
#  2   traffic   500 non-null    float64
#  3   speed     499 non-null    float64
#  4   rain      500 non-null    float64
#  5   fare      500 non-null    float64
# dtypes: float64(6)
# memory usage: 23.6 KB

# %%
#fill 

data.dropna(inplace=True) #harja null ro hazf konim

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 497 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   distance  497 non-null    float64
#  1   duration  497 non-null    float64
#  2   traffic   497 non-null    float64
#  3   speed     497 non-null    float64
#  4   rain      497 non-null    float64
#  5   fare      497 non-null    float64
# dtypes: float64(6)
# memory usage: 27.2 KB

# %%
#oon sotoni k float nist

#data['Duration'] = data['Duration'].astype(float)
#data['Trafic'] = data['Trafic'].astype(float)


data.describe()

#sped 800 , agah mashin 800 bashe

#rain , ...

#data = data[data['speed'] < 1000]
# Out:
#          distance    duration     traffic       speed        rain        fare
# count  497.000000  497.000000  497.000000  497.000000  497.000000  497.000000
# mean    15.161762   44.469077    0.517947   64.480688    0.499386   83.500922
# std      8.804914   25.103544    0.297660   31.601570    0.285932   30.604261
# min      0.649317    2.407618    0.004940   10.354009    0.001565   16.027666
# 25%      7.567076   22.174123    0.242045   36.476198    0.261706   61.710921
# 50%     15.606745   43.541891    0.539491   65.675605    0.494212   84.308449
# 75%     22.759015   65.863317    0.779584   91.056112    0.743193  105.175236
# max     29.792461   89.975155    0.999414  119.818226    0.995438  156.945863

# %%
data.duplicated().sum()

#data.drop_duplicates(inplace=True)
# Out:
# 0

# %%
data.reset_index(drop=True,inplace=True)

# %%
data.head()
# Out:
#     distance   duration   traffic      speed      rain        fare
# 0  11.548934  63.438231  0.185133  67.098996  0.261706   84.395736
# 1  28.546072  49.176480  0.541901  62.710007  0.246979  121.224703
# 2  22.093821  29.238430  0.872946  12.820627  0.906255   99.720935
# 3  18.160425  73.613962  0.732225  47.537261  0.249546  117.325635
# 4   5.102550  62.256343  0.806561  51.821518  0.271950   76.033862

# %%
#tabdil konim data ra b x , y 
#fek kon yek mdoel dari train mibine , tahesh ch estefade ei mikhahi anjam dahi??? 
#migi agha man dar ayande mikhamy app besazam , rooye khode mashin haye taxi bashe (ubber bashe) taraf vaghty safaresho rft
#bar asase in maolefe ha , baid pishbini jkone, takhmin bzane , ketayat inghadre

#vorodie shoma --> moalefe hae  k gofti --> khoroji chizie k mikhay pioshbini (fare , keraye)

#donbale peyda krdne rabetey beyne keraye va moaelfe a hasti

# fare = a * distance + b * duration + c * trafic + d * speed + e * rain + f  

#distance , duration , trafic , speed , rain ---> [BOX] --> Fare

#A,B,C,D,E,F --> az koja yad grfte mishe? az roye data

# %%
import matplotlib.pyplot as plt

plt.scatter(data['distance'],data['fare'],s=5)
plt.xlabel('Distance')
plt.ylabel('Fare')
plt.title('Distance vs Fare')
plt.show()

# %%
for column in data.columns:
    if column != 'fare':
        plt.figure(figsize=(10,6))
        plt.scatter(data[column],data['fare'],s=5)
        plt.xlabel(column)
        plt.ylabel('Fare')
        plt.title(f'{column} vs Fare')
        plt.show()

# %%
#pip install seaborn

import seaborn as sns 

sns.pairplot(data)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# Make data
# Plot
x1 = data['distance']
x2 = data['duration']
y = data['fare']
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.scatter(x1,x2,y)


plt.show()

# %%
#3d --> tasmim begiri kodom x haro mikhay 

#distance, duration --> fare

#x ->dustance, duration 
#y-->fare


x1 = data['distance']
x2 = data['duration']
y = data['fare']

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

scatter = ax.scatter(x1, x2, y, c=y, cmap='viridis', alpha=0.6)

ax.set_xlabel('Distance (x1)')
ax.set_ylabel('Duration (x2)')
ax.set_zlabel('Fare (y)')
ax.set_title('3D Scatter Plot: Distance, Duration vs Fare')

fig.colorbar(scatter, ax=ax, label='Fare')
plt.tight_layout()
plt.show()

# %%
data.columns
# Out:
# Index(['distance', 'duration', 'traffic', 'speed', 'rain', 'fare'], dtype='object')

# %%
#tabdil b x, y

#x --> in chizhaee hast k moteghayer hast va taghir mikonad va bar asasaash
#Mikhaham dar usage phase , fare ro (kraye) takhmin bznm

x = np.array(data[['distance','duration','traffic','speed','rain']])
y = np.array(data['fare'])



# y = a*x1 + b*x2 + c*x3 + d*x4 + e*x5 + f


#Linear regression

from sklearn.linear_model import SGDRegressor

model = SGDRegressor(loss='squared_error',learning_rate='constant',eta0=0.0001,max_iter=1000,random_state=42)


model.fit(x,y) #bere hamin kari , statistcialy  khjat haye motefavet

#  y1 = 10*x1 + 20*x2 + 30*x3 + 4*x4 + 50*x5 + 60 --> prediction - vagheiat -> LOSS1
#  y2 = 3*x1 + 20*x2 + 4*x3 + 40*x4 + 50*x5 + 23 --> prediction - vagheiat -> LOSS2
#  y3 = 4*x1 + 20*x2 + 30*x3 + 3*x4 + 50*x5 + 632 --> prediction - vagheiat -> LOSS3
#  y4 = 4*x1 + 4*x2 + 32*x3 + 23*x4 + 23*x5 + 12 --> prediction - vagheiat -> LOSS4


#kamtarin loss --> a,b,c,d,e,f ro bebinim 


a = model.coef_
b = model.intercept_


print('a = ',a)
print('b = ',b)
# Out:
# a =  [ 2.70317612  0.87100133  2.81971823 -0.05106231  1.56228414]
# b =  [1.60721815]

# %%
print('y = ',a[0],'* x1 + ',a[1],'* x2 + ',a[2],'* x3 + ',a[3],'* x4 + ',a[4],'* x5 + ',b)


print('fare = ',a[0],'* distance + ',a[1],'* duration + ',a[2],'* traffic + ',a[3],'* speed + ',a[4],'* rain + ',b)
# Out:
# y =  2.703176124462583 * x1 +  0.8710013266743879 * x2 +  2.8197182269537726 * x3 +  -0.051062310100209424 * x4 +  1.5622841360258857 * x5 +  [1.60721815]
# fare =  2.703176124462583 * distance +  0.8710013266743879 * duration +  2.8197182269537726 * traffic +  -0.051062310100209424 * speed +  1.5622841360258857 * rain +  [1.60721815]

# %% [markdown]
# shoam distance, duration traffic, rain, --> mziare in formula va keraye ro hesab mikone

# %%
new_x = np.array(1).reshape(-1,1)

model.predict(new_x)

#X has 1 features, but SGDRegressor is expecting 5 features as input.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[83], line 3
#       1 new_x = np.array(1).reshape(-1,1)
# ----> 3 model.predict(new_x)
#
# File ~/anaconda3/envs/DL/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:1691, in BaseSGDRegressor.predict(self, X)
#    1678 def predict(self, X):
#    1679     """Predict using the linear model.
#    1680
#    1681     Parameters
#    (...)
#    1689        Predicted target values per element in X.
#    1690     """
# -> 1691     return self._decision_function(X)
#
# File ~/anaconda3/envs/DL/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:1673, in BaseSGDRegressor._decision_function(self, X)
#    1660 """Predict using the linear model
#    1661
#    1662 Parameters
#    (...)
#    1669    Predicted target values per element in X.
#    1670 """
#    1671 check_is_fitted(self)
# ...

# %%
data.columns
# Out:
# Index(['distance', 'duration', 'traffic', 'speed', 'rain', 'fare'], dtype='object')

# %%
new_x = np.array([100,20,0.3 , 120 , 0.9]).reshape(1,-1)

model.predict(new_x)

#100*a[0] + 20*a[1] + 0.3*a[2] + 120*a[3] + 0.9*a[4] + b --> keraye
# Out:
# array([285.46935111])

# %% [markdown]
# ------
#
# # Regression and CLassification (Statistcially)
#
# Ta inja regressione khatie amari ro yad dadim harfi az ML ,....
#
# hala mikham yek chize dg --> classification begam chi hast .......

# %% [markdown]
# x vorodi , y khorojie . rabetey beyne x o y
#
# y = a* x + b ro nemikhahid
#
#
# bar asase x---> [] --> y kodom dastas , daste 1 , daste 2 ,.....
#
# Ma yekseri gol darim . 20 ta gol darama . raftim gol haro arz (khode ghonchash) va toolesho (saghesho) . va jolosh label zadim .
#
# arz     tool        noe gol
# 5        10        yasaman  <br>
# 6        12       yasaman  <br>
# 5         18      yasaman  <br>
# 8         9      yasaman <br>
# 9         14    yasaman <br>
# 10        20     yasaman <br>
#
# 15       15      roz <br>
# 20       18      roz <br>
# 23       17      roz <br>
# 18      16       roz <br>
# 17       20      roz <br>
# 16       22      roz <br>
# 20       24      roz <br>
#
#
#
# aya moitonam yek systemi besazam  , beehsh tool va arze gol ro bdim va tashkhjis bede k in gol yasamane ya roze
#
# man mese regressin donbalke adad nistan , taravate gol ro dr , mikham typesho dar bairam
#
#
# data haro daram (jam avair krdm ) RL . kame (DL) <br>
# vorodi khorojhi drm , khoroji ham label khorde . unsupervised nist<br>\
# y khorojie man daste bandie -> supervised classification <br>

# %%
import numpy as np

# x1 = arz column
x1 = np.array([5, 6, 5, 8, 9, 10,        # yasaman
               15, 20, 23, 18, 17, 16, 20]) # roz

# x2 = tool column
x2 = np.array([10, 12, 18, 9, 14, 20,      # yasaman
               15, 18, 17, 16, 20, 22, 24]) # roz

# label: yasaman = 0, roz = 1
label = np.array([0, 0, 0, 0, 0, 0,         # yasaman (6 samples)
                  1, 1, 1, 1, 1, 1, 1])      # roz     (7 samples)

c_label = ['blue','blue','blue','blue','blue','blue','red','red','red','red','red','red','red']


#plt.plot('temeprature (x) ' , 'estehkam (y)')

#-->x haro rasm mikoni

plt.scatter(x1,x2,c=c_label)
plt.xlabel('arz')
plt.ylabel('tool')
plt.title('arz va tool')
plt.show()

# %%
x_range = np.linspace(0,25,100)
a= -1
b=10
y_range = a * x_range + b
plt.scatter(x1,x2,c=c_label)
plt.plot(x_range,y_range,color='black')
plt.xlabel('arz')
plt.ylabel('tool')
plt.title('arz va tool')
plt.show()

# %% [markdown]
# loss function --> tedade gol haee k vaghean too dasteye khodeshon oftadan ,6/13 * 100 --> 48%

# %%
x_range = np.linspace(0,25,100)
a= -1
b=20
y_range = a * x_range + b
plt.scatter(x1,x2,c=c_label)
plt.plot(x_range,y_range,color='black')
plt.xlabel('arz')
plt.ylabel('tool')
plt.title('arz va tool')
plt.show()

# %% [markdown]
# loss function --> tedade gol haee k vaghean too dasteye khodeshon oftadan ,3/13 * 100 --> 25%

# %%
x_range = np.linspace(0,25,100)
a= -1
b=25
y_range = a * x_range + b
plt.scatter(x1,x2,c=c_label)
plt.plot(x_range,y_range,color='black')
plt.xlabel('arz')
plt.ylabel('tool')
plt.title('arz va tool')
plt.show()

# %% [markdown]
# 1/13 --> 5 %

# %%
x_range = np.linspace(0,25,100)
a= -1.1
b=31.5
y_range = a * x_range + b
plt.scatter(x1,x2,c=c_label)
plt.plot(x_range,y_range,color='black')
plt.xlabel('arz')
plt.ylabel('tool')
plt.title('arz va tool')
plt.show()

# %% [markdown]
# a=-1 , b=10 --> 48 % <br>
# a= -1 , b=20 --> 25 % <br>
#  a= -1 , b=25 --> 1/13 --> 5 % <br>
#  a=-1.1 , b = 31.5 --> 0/13 <br>
#
# inja ham miram hey a , b ro taghir mdiam k khati rasm konm , ama nmiram loss function = y_pred - y_true (regression) <br>
# mibinam chanta doros tashkhis --> number --> loss fucntion
#
# az beyne anhaee k kamtarin los function --> a, b
#
#
# predction
#
# arz , tool --> ,paeene khat --L> yasamn , balaye khat --> roz
#
# ```python
#
#
# class felanclasssifier(x,y):
#
#     def __init__(setting,,....):
#         pass
#
#     def fit(self,x,y):
#
#         #a , b ,... gradient ,...
#
#         #loss fucntion
#
#         _loss_function()
#
#         #paen tarin a , b ro dar maire
#
#         #self.a
#         #self.b
#
#
#     def _loss_fucntion():
#         '''
#         Fargjeh aval
#         bejaye y_true - y_pred miaym numebr miss classification ro hesba mikonim
#         '''
#
#
#
#     def predict(new_x):
#         '''
#         bejaye inke biad y_pred = a* new_x + b  returnb y_pred
#
#         miad too a , b
#
#         x --> a* new_x + b --> ye adad
#
#         if adad < khat --> too daste class 0
#         else --> balatr --> daste classs 1
#
#         return class 0 , class 1
#         '''

# %%
import numpy as np

# x1 = arz column
x1 = np.array([5, 6, 5, 8, 9, 10,        # yasaman
               15, 20, 23, 18, 17, 16, 20]) # roz

# x2 = tool column
x2 = np.array([10, 12, 18, 9, 14, 20,      # yasaman
               15, 18, 17, 16, 20, 22, 24]) # roz

# label: yasaman = 0, roz = 1
label = np.array([0, 0, 0, 0, 0, 0,         # yasaman (6 samples)
                  1, 1, 1, 1, 1, 1, 1])      # roz     (7 samples)




#data --> pandas
# x = data['arz','tool']
# y = data['label'] 

x = np.array([x1,x2]).reshape(-1,2) #dota radi krdm
y = label

from sklearn.linear_model import LogisticRegression

model = LogisticRegression()


model.fit(x,y)
# Out:
# (13, 2)
# LogisticRegression()

# %%
model.predict(np.array([10,15]).reshape(1,-1))
# Out:
# array([0])

# %%
model.predict(np.array([20,30]).reshape(1,-1))
# Out:
# array([1])

# %% [markdown]
# -------
#
# # Review untill here
#
# AI chan ravesh dre
#
# Supervised --> data (x,y ) y ham hast --> y peyvaste --> Regression, gosaste --> classificatin  <br>
# unsupervised -> data (x) --> y nist 0--> pas donable clustering, --> unsupervised <br>
# reinforcement learning(RL) --> dataee nadarim amade, balke data besoorate continious peyvaste hey vared beshe donedone <br>
# Deep learning (DL) --> edamweye rahe supervised,unsupervisde, data kheyli ziad darim, memari ee has k supervised , iunsupervuised estefae mish ama deep tar, architecture complex tari daree <br>
#
#
# ### Statistical regression bebinim chie
#
# khode regression, yani ma yekseri X darim va donbale peyda krdnsh ba y hastim <br>
# hala y = a* x + b  , y = a*x1 + b*x2 + .... + f <br>
#
# ravesh haye otefaveti has
#
# 1 - Fitting phase 1 <br>
# SGD linear regression --> khat haye motefavet ba a,b,c,,... rasm mikone [raveshe] <br>
# loss functon hesab mikone --->  faseleye beyne y_pred (khati k sakhte) , experimental data (vaghei , true)
#
# az byne tamam ein ha (parameters) --> minimum loss function --> Gradient descent --> hoshmandane  <br>
#
# y = a*x1 + b*x2 --> khat ro peyda krde
#
# 2- Usage phase (inference) <br>
# khat ro darim voroodi --> BOX --> khoroji <br>
#
# x1,x2,x....--> khat --> y ro hesba mikone pas mide
#
#
# ravesh haye dg hamine -->  <br>
# dataro x, y . donbale rabteye y va x .
#
# miad yek raveshe amari mziane --> loss function . beyen ina behtrin loss fucniton . khate khdoesho manteghesho
#
# uysage pahse --> vorodi m dii , toye raveshe amri --> khoroji pas mide
#
#
# ### statistical classification
#
# dg ma donbale rabetye beyne y va x nistin.
#
# y chon adad nist , y dar al yek label hjast , darad nadarad, geron hast nist, badkhim khosh khim . ysaman roz nastaran ... <br>
#
# ma donbale yek raveshi hastim k betavanim beyne x ha tafavot ijad kone,
#
# LOgisticregression --> Classification .*****
# miad inja yk khat miekshe va loss fucntion --> tedade pishbini haye ghalat , miss classifictaiob hate ghalat <br>
# miad fdonbael minimum loss funciton --> in parametre <br>
#
# hala too preddiction --> vaghty vroodii midi bar asase mnateghes (yek khat dare mibine paeneshe ya balahse) --> in kodom clas shasrt ...
#
#
#
#
# ---------
# ## Stastical models vs Machine learning models
#
#
# har modeli k dashtim migofti awlie tamam , vali nemididim agah in model vaghean b dard mikhore? mioshe estefade krd azash ? chegahdr relaible ?
#
# age peyda nakard chi rabetaro <br>
#
# har mdoel miodel.fit() --> model.predict()
#
#
# model.fit() --> model.predict() --> khosh khim badkhim . <br>
# badkhim --> khosh khim tashkhis -> khatare marg <br>
# khosh khim -. badkhik =-> bahse mali , hazineye mali <br>
#
# man bayad yejori betonam bebinam modelam aya doros pishbini mikonad ya na?? <br>

# %%
temperature = [10,20,40,60,80,100]
estehkam = [105 , 197  , 401  , 605 , 809  , 1013]

x  = np.array(temperature).reshape(-1,1)
y = np.array(estehkam)


from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(x,y)
new_x = np.arange(0,150,1).reshape(-1,1)
y_pred = model.predict(new_x)





plt.scatter(x,y,label='experimental data')
plt.plot(new_x,y_pred,color='red',label='linear regression')
plt.title('temperature va estehkam')
plt.xlabel('temperature')
plt.ylabel('estehkam')
plt.xlim(0,150)
plt.ylim(0,1500)
plt.grid()
plt.legend()
plt.show()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [10.13150685]
# -1.7945205479452397

# %% [markdown]
# omadam be CEO (raese sherkat) migam k bebin man yek model sakhtam temperature--> behet estehkam mide. dg shoam naizi nadari beri dama set kjoni, azmayesh koni 1 saaat, 2 saat asard, 2 saat tst begiri ta bbini chande .
#
# in khedmate shoma . <br>
#
# raese shekrat mige koo bebiionam  <br>
#
# estehkam = 10.1315 * dama - 1.7945

# %% [markdown]
# temperature = [10,20,40,60,80,100] <br>
# estehkam = [105 , 197  , 401  , 605 , 809  , 1013] <br>
#
#
# man miram damaye 30 daraje , 90 daraje karkoan -> beran toldi konan , estehkam bgirn dota estehakm midan .

# %%
#coef* 30 + intercept 
#coef* 90 + intercept 


pred_30 = model.predict(np.array([30]).reshape(1,-1))
pred_90 = model.predict(np.array([90]).reshape(1,-1))


print('predicted estehkam for 30 degree: ', pred_30)
print('predicted estehkam for 90 degree: ', pred_90)


#esme oona mizare --> True

#chizi k man mizanam --> prediction
# Out:
# predicted estehkam for 30 degree:  [302.15068493]
# predicted estehkam for 90 degree:  [910.04109589]

# %%
true_30 =  np.array([310.2322])

true_90 = np.array([908.332123])



#chanta ravesh daram k in fasele ro hesab konm 

#done done inaro - ham konm 


#y_true - y_pred


#908 - 910 = -2 , 310 - 302 --> 8     sum--> khata -->6
#908 - 915  = -7 , 310 - 302 -->8    sum--> khata = 1

#absolute migirasm  , sum , mean 

#agar biam mean ( |True - predic tion |)

#908-910 = -2 -->|| --> 2
#310 - 302 = 8 ->|| --> 8 
# 6 -->  khataye man 

#yani agha miangin khatye man +- 6 har megdhai k bedi --> Mean Absolute error --> MAE

#khata / khodesh --> darsad mdie -> 2% ,3% ---> Mean absolute percentage error --> MAPE

#khata **2 --> mean squared error --> MSE

#betavane 2 konam mean , raidcsl --> Root Mean Squared Error --> RMSE

# %% [markdown]
# ManTEGH INJA in hast k ma hameye dataee k darim ro b do ghesmat taghsim konim , yeki esmesho bzar train (fit koni karato ,.), yedone ro esmesho bezar (test) , in test yani yek dataee hast k modele to nadidatash , jadide, new , pas agar in haro pishbini koni yani jadidiii.

# %%
temperature = [10,20,40,60,80,100]
estehkam = [105 , 197  , 401  , 605 , 809  , 1013]

x  = np.array(temperature).reshape(-1,1)
y = np.array(estehkam)

plt.scatter(x,y)
plt.ylabel('estehkam')
plt.xlabel('temperature')
plt.legend()
plt.show()
# Out:
# /var/folders/dz/4n_kltlx7kd_62c5j4d4vf0w0000gn/T/ipykernel_48743/1483620964.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#pandas ..... 



#step 0.0 --> cleaning data

#step 0.1 --> tabdil b x, y 

temperature = [10,20,40,60,80,100]
estehkam = [105 , 197  , 401  , 605 , 809  , 1013]

x  = np.array(temperature).reshape(-1,1)
y = np.array(estehkam)


#step 0.2 --> train test split --> taghsim kon

from sklearn.model_selection import train_test_split

#test siuze --> chan darsad ro man test begrim az datahat

#0 -1    --> 0.2 --> 20% 

#20 , 25 % 
#20 % az avale nemonat vardaram, nemonato  ham bezanam (shuffle ) lkom k 

#random varmdiare
#har dafe ino run koni , yechi vrmidare

#random_state --> seed --> sabet koni , 42 ,..

#hamihse har dafe run koni , daghighan hamoni k random dafe aval vardashte ro varmidare 
#reporudcibile 

#random_state -> shedate shuffle --> 0 -10000 --> 42  developer 

#in tabe miad x , y ro 0.2 test mikone , 0.8 train .  shuffle besorate random , hamishe ham rporducible 

#train_test_split(x,y,test_size=0.2, shuffle=True,random_state= 42)

# train test ??

#data --> train ata , test data


#x , y ---> x_train , y_train     | x_test , y_test


x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2, shuffle=True,random_state= 142)


#miad x , y ro 0.2 test kone, 0.8 train (random) -->khoroji x_train, x_test , y_train , y_test


plt.scatter(x_train,y_train,label='train data',color='blue')
plt.scatter(x_test,y_test,label='test data',color='red')
plt.xlabel('temperature')
plt.ylabel('estehkam')
plt.legend()
plt.show()

# %%
print('x_test: ', x_test)
print('y_test: ', y_test)
# Out:
# x_test:  [[20]
#  [40]]
# y_test:  [197 401]

# %%
print('x_train: ', x_train)
print('y_train: ', y_train)
# Out:
# x_train:  [[ 10]
#  [ 80]
#  [ 60]
#  [100]]
# y_train:  [ 105  809  605 1013]

# %% [markdown]
# ------
# -------
# -------

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


#data ro improt mikone --> pandas ,....

#step 0.0 --> data cleaning    1-empty cell 2- type 3-logic 4-duplciated reset_index() .info()....
# step0.1 -> tabdil b x , y (np.array)
temperature = [10,20,40,60,80,100]
estehkam = [105 , 197  , 401  , 605 , 809  , 1013]

x  = np.array(temperature).reshape(-1,1)
y = np.array(estehkam)



#step 1 --> train test split --> SHoroe machine learning
from sklearn.model_selection import train_test_split

x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2, shuffle=True,random_state= 142)



#-------Phase training (Fit)
#step 2 --> model 
#regression 
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import LinearRegression
#model = SGDRegressor(loss='squared_error',max_iter=1000,tol=1e-3,random_state=42)
model = LinearRegression()


#model.fit(x,y) rooye hameye datat fit mikardi (train ) midadi --> fght bayad rooye datahaee statsitcial
model.fit(x_train,y_train)  #b raveshe khdoesh (a,b,, loss fucntion minimum ,..)


print('model.coef_: ', model.coef_)
print('model.intercept_: ', model.intercept_)


y_train_pred = model.predict(x_train)


plt.scatter(x_train,y_train,label='train data',color='blue')
plt.plot(x_train,y_train_pred,label='predict data',color='red')
plt.xlabel('temperature')
plt.ylabel('estehkam')
plt.legend()
plt.show()
# Out:
# model.coef_:  [10.08268156]
# model.intercept_:  2.832402234636902

# %%
#Evaluation phase --> arzyabi kjonam

#pas fght x ro midam b model
y_test_pred = model.predict(x_test)

y_true_test = y_test


#faseleye beyne vaghei k bode y_test ba chi bgirm ? y_pred --> mdoele man pishbini krde (x-test)

#MAE , MSE , RMSE , MAPE

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score , mean_absolute_percentage_error

#tabe metrics (y_true , y_pred) vagheiat  , predict

mae = mean_absolute_error(y_true_test,y_test_pred)  #done done | pishbini haro - vagheait |  mean hame noghte 
mse = mean_squared_error(y_true_test,y_test_pred) # |pishbini haro - vagheiat | **2  --> mean 
rmse = np.sqrt(mse) #rooye miangine MSE --> radicale


mape = mean_absolute_percentage_error(y_true_test,y_test_pred) #done done |pishbini - vaeghaiat |/ pishbini --> darsad khata

r2 = r2_score(y_true_test,y_test_pred) # khodesh raveshe amari --> standard deviation -> error haro mitone mdoel amari tozih bde 


print('mae: ', mae)
print('mse: ', mse)
print('rmse: ', rmse)
print('mape: ', mape)
print('r2: ', r2)
# Out:
# mae:  6.312849162011204
# mse:  41.22842607908657
# rmse:  6.420936542209911
# mape:  0.025408644681578083
# r2:  0.9960372523953204

# %%
#yani modele man +- 6.32 estehkam ro eshtebah pishbini kard baraye opon dota noghte nadidam
#r2 --> 0 , 1 --> 0.98 --> toneste besorate amari tozih bde error haro

#mape --> darsade khata 0--0> 0 -1 --> 0.02 --> *100 --> 2% khataye mdoel eman 2% hast

#test error --> 

#MAE TEST ERROR --> +- 6.32
#MAPE TEST ERROR --> 2% khata

# %% [markdown]
# # 4 ta soale jalaseye ghabli k dashtim joda azinke --> shoam mojadad bayd hal konid
#
#
# #Q7
#
# #model = linearregression()
# #model = SGDRegressor()
#
# #lotf konid ba train test split ham halesh konid
#
# # 4 TA DATA
#
#
# '''
# data1
#
# MAE, MAPE ,MSE , RMSE, R2 --> Linearegression()
# MAE, MAPE ,MSE , RMSE, R2 --> SGDRegressor()
#
#
# data2
#
# MAE, MAPE ,MSE , RMSE, R2 --> Linearegression()
# MAE, MAPE ,MSE , RMSE, R2 --> SGDRegressor()
#
#
# data3
#
# MAE, MAPE ,MSE , RMSE, R2 --> Linearegression()
# MAE, MAPE ,MSE , RMSE, R2 --> SGDRegressor()
#
#
# data4
#
# MAE, MAPE ,MSE , RMSE, R2 --> Linearegression()
# MAE, MAPE ,MSE , RMSE, R2 --> SGDRegressor()
#
#
#
#
# '''
