# %% [markdown]
# # Signal Processing
#
# Signal processing means analysis, change, clean, convert , feature extaction of signals.
#
# but signal si something that values change with tiem or place
#
#
# ```bsh
# Amplitude
#    ^
#    |
#    |       /\       /\
#    |      /  \     /  \
#    |_____/____\___/____\______> Time
# ```
#
#
# for instance liek human voice that in each time we have one valuye,,and we can say $$x(t)$$
#
# when you say 'hello' it change
