# %% [markdown]
# # Ai Other architectures
#
# Ma base ro midonim --> Neural Networks --> Shabake asabi
#
# Ommadan baraye karbord haye motefavet , dast bordan tooye memarie ma
#
#
# Aya lazem hast tamame in memari haro balad bashim ? Kheyr
#
#
# bebinid har memari , CNN , RNN , LSTM , GAN ,.....
#
# CNN --> 30 memarie mtoefavet , enghlabi alexnet , resnet ,....
#
#
# Neural network kamel befahmi, tamame fahme in entwork ha sadast , sade tar mishe , ama baraye fahme 100 darsad
#
#
# Resnet -> 20 saat zaman bezarid --> khode resnet ro bekhahid az aval bshinid memarisho benevisid va run konid
#
# jalase ye badi --> Transformers , ma yek seri memari darim ina amade hastan , ma fgth bayad memwrish va freez konim . train shodan weight hashono daran ma mitonim azashon estefade konim mostaghim .
#
#
# baraye masaleye khoddmon fght o fght yek seri laye hasho azad zbarim , hame laye haro freez konim , fine tune konim rooye dataye khodemon .  weight ha b gone ei taghir kone k nesbat b datasete ma ro learn krde bashad.
#
#
# Memari haro b soroate moroi migam , code zani migam , ama ma hichvaght ghrar nis az sefr yek memamri ro code bznim . agar lazem bashad bezanim --> naiz hast hadeaghal oon memari ro 20 ta 30 saat, yek ketab rajebesh bekhonid.
#
#
#
# Ma base ro yad grftim, omadan chandind memarie madar sakhtan , k frgh dare , concept haye jadid . too dele hamina hezzran memarie kochak hast
#
#
#
#
#
#
# ------
# ------
# # CNN (Convoluitional Neural Network)
#
#
# Vaghty ma tooye MNIST --> omdim yek tasvir bod 28 x 28 pixel omdim hamaro kandim --> 784 X bara har tasvir
#
# 300 neuron --> 726 * 300 = 217800 weights -> tedad baal
#
# moshekele dovom --> sakhtare data az beyn rafte .  pixel haye kenae ham mohem trn, goshe gorbe kenare cheshm.
#
# biad sakhtare dade ro negah darim ,
#
#
# CNN -->
#
# 28 x 28 -> 784 numbers flatten --> dense(128) -->
#
# ![CNN](https://media.geeksforgeeks.org/wp-content/uploads/20250503115950473786/Kernels-in-convolutional-neural-network.webp)

# %% [markdown]
# Mige bioa axo kamel pixel pixel ba hamon sakhatr bezarim, yek kernel darim (mrtone 3x3 , 4x4 ,....) ke toosh yekser=i weigth (learn) pas baes mishe yek axe 28 x 28 --> (kernel)--> feature map
# ![cnn_calculation](https://mlnotebook.github.io/img/CNN/convExample.png)
#
#
# baraye tak tak kernel ooye hame tasvir harekat mikone
#
# ![cnn_gif](https://mlnotebook.github.io/img/CNN/convSobel.gif)

# %% [markdown]
# Dar rgb zamani k shoam 3 ta matrix darim baraye reg, green , blue
#
# ![rgb_cnn](https://towardsdatascience.com/wp-content/uploads/2019/10/10rTv7bUJbpsEceQ9Ksz6iA.png)

# %% [markdown]
# ```bsh
# 1  2  0  1  3
# 0  1  2  2  1
# 1  0  1  3  1
# 2  1  0  1  0
# 1  2  2  0  1
# ```
#
# bad az kernel
#
#
# ```bsh
# 1   0  -1
# 1   0  -1
# 1   0  -1
# ```
#
# miad elemnt-wise 1 + 0 1- + ... --> yek adad
#
#
#
#
# tabdil shdoe b featur emap.
#
#
# kernel rooye kole tasviur harkeat krde va yek majmoei khoroji matrix jadid darim
#
# Image --> Harekate kernel -> Feature map.
#
#
# Filter(kernel) --> kabe haye axo , lgoshe ha , texture ,...
#
# ensan negah mikone, mohito mibine, tasviro mibini badano
#
# tasvir zoomd
#
# kernel rooye feature
#
# dar akahr inghad kochik mishe miad tabdilesh vaslesh b neural network . neuron --> sag gorbe
#
# adame, gheyre adam
#
#
# az yejkseri number (Matrix ax)  (kernel ) --> fewature map --> ta inghd feshorde --> yek neuron (sag gorbas)
#
#
# avalin bar --> weight ha random, yek ax --> 237 , adade vagehue --> 1
#
# loss fucntioin gradient ---> weight ha b gonei bshn zamani k ax ro dadi B CNN --> 1 , 0
#
#
#
#
# ----
#
# 1- Sakhtare ata hefz shod ,
#
# 2- 784 * 128 = 100 352 weights,  32 ta filter 3 x 3 (kernel) --> 288 weights
#
#
#
# Linear --> compelx --> rooye feature map (kernel) zigma zire yek activatiion fucntion .
#
# mikhahi dobare abad ro kahesh bedi --> Polling
#
# 28 x 28  ---> pooling --> 14 x 14
#
# max poooling
#
#
#
# average pooling
#
# ![max_avg_pooling](https://www.researchgate.net/publication/333593451/figure/fig2/AS:765890261966848@1559613876098/llustration-of-Max-Pooling-and-Average-Pooling-Figure-2-above-shows-an-example-of-max.png)

# %% [markdown]
# kaheshe andaze feature map, kaheshe comptuation (mohasbeat  ,afzayeshe effeci=tuev receotive field) , hefze feature haye barjeste --> maxpoling estefade krdnd
#
#
# ma dar nahayat daghighan mesle yek neural network --> layer haee darim k omdn vasatesh chandin filter gozahstim (kernel (weights) ) zarb shode dareshoonm ham sakhtar negah dahste shode , ham etedade weight kam (computation) , bad azon hata feature map hae k mide too har laye , pooling ,
#
# lyae haye avalie --> Edge, line, simple pattern
#
# layer haye vasat --> texture, shape , parts
#
# layer haye amigh --> eyes, ears, faces , object
#
#
# ```bsh
# Pixels
#    ↓
# Edges
#    ↓
# Textures
#    ↓
# Shapes
#    ↓
# Object Parts
#    ↓
# Object
# ```
#
# Hierarchical feature leanrning
#
#
#
# MNIST 28 x 28
#
# CNN
# ```bsh
# Input
# 28×28×1
#    │
#    ▼
# Conv 3×3, 32 filters
#    │
#    ▼
# ReLU
#    │
#    ▼
# MaxPool 2×2
#    │
#    ▼
# Conv 3×3, 64 filters
#    │
#    ▼
# ReLU
#    │
#    ▼
# MaxPool 2×2
#    │
#    ▼
# Flatten
#    │
#    ▼
# Dense
#    │
#    ▼
# 10 Classes
#
# ```

# %%
import tensorflow as tf  
from tensorflow.keras import layers, models 


model = models.Sequential([
    layers.Input(shape=(28,28,1)),

    #layer 1 (conv + relu + maxpool )
    layers.Conv2D(filters=32, kernel_size=(3,3) , activation ='relu'),

    layers.MaxPooling2D(pool_size=(2,2)),


    #layer 2
    layers.Conv2D(filters=64, kernel_size=(3,3) , activation ='relu'),

    layers.MaxPooling2D(pool_size=(2,2)),


    #hamaro flatt --> chandin neuron
    #layer 3
    layers.Flatten(),

    #NN --> 728 * 128 * 64 * 32 * 10 
    #CNN --> -->conv1 --> conv2 -_> 128 --> 10
    layers.Dense(128,activation = 'relu'),

    layers.Dense(10,activation='softmax')

])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1600)           │             0 │
# ...

# %% [markdown]
# #comiler , fit ,....

# %%
import torch  
import torch.nn as nn

class CNN(nn.Module):

    def __init__(self):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channels=1, out_channels=32, kernel_size=3, padding=1) 

        self.pool = nn.MaxPool2d(2,2)

        self.relu = nn.ReLU()

        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1)

        self.flatten = nn.Flatten()

        self.fc1 = nn.Linear(in_features=64*7*7, out_features=128)

        self.fc2= nn.Linear(in_features=128, out_features=10)

        self.softmax = nn.Softmax(dim=1)

    def forward(self,x):

        x = self.conv1(x)
        x = self.relu(x)
        x = self.pool(x)

        x = self.conv2(x)
        x = self.relu(x)
        x = self.pool(x)

        x= self.flatten(x)

        x= self.fc1(x)
        x = self.relu(x)

        x = self.fc2(x)

        x = self.softmax(x)

        return x

# %% [markdown]
# ## hISTORY OF CNN
#
# #LeNet --> Yann leCun (meta ai )  1998
#
# avalin bar sakht baraye MNIST
#
# ```bsh
# Input 32×32
#
# ↓
#
# Conv
#
# ↓
#
# Average Pooling
#
# ↓
#
# Conv
#
# ↓
#
# Pooling
#
# ↓
#
# Fully Connected
#
# ↓
#
# Output
# ```
#
# Rooye datahaye bizorg khob nabod, GPU ssan
#
#
# ## Enghelab AlexNET 2012
#
# imagenet -_> 1 million tasvir --> hezar class --> telephone , ..
#
# geoffery hinton (Alexa) --> alexnet -> pooling, avalin abr dar tarikh az GPU
#
# ```bsh
# Input Image
#
# ↓
#
# Conv
#
# ↓
#
# ReLU
#
# ↓
#
# Pooling
#
# ↓
#
# Conv
#
# ↓
#
# ReLU
#
# ↓
#
# Pooling
#
# ↓
#
# Fully Connected
#
# ↓
#
# 1000 classes
# ```
#
# dropout --> yekseri neuron haro mikoshe, random -> kole network overfit , depend nabashe hatman .
#
#
# ## VGG Network
#
# 2014
#
#
# sade ama amigh , bejaye inke az kernel 11x11 estefade, az chand 3x3 behtare.
#
# 7 x7 dqar asl mesle 3 ta conv 3x3
#
# conv kochiktr --> parmaetr kamtar, non lkinearity bishtari -> complex
#
# 7 x7 --> 49 parameter .   3 ta 3x3 --> 27 parameter
#
#
# VGG16
# 13 conv layers + 3 fully connected layers -> 16 layers
#
# 138 Million parameters -->
#
#
# amigh bood, vaghty b avayele barmigsahts los -> vanishing gradient , gradient inghd kochik bshe --> va avayele network dg oon formul update weight , w new = w old -> train nashe
#
#
# ## ResNet
# 2015 omd va az yek layer mapping kamel estefade krd
#
# H(x) ,
#
# output = F(x) + x -- > residual connection
#
# ```bsh
# x
#
# ↓
#
# Conv
#
# ↓
#
# Conv
#
# ↓
#
# Output
#
# ```
#
# inkaro kon
#
# ```bsh
#        x
#        |
#        |
#        +--------+
#                 |
# x → Conv → Conv |
#                 |
#                 +
#                 |
#               Output
#
# ```
#
# skip connection
#
# gradient tooye yek backpropagation sade traidtional chan masir dahstim va hamn baes smishod gradientemon bmoroe zaman vanish , vali hala yek skip conection drim k backpropagation baraye gradient yek masire mostaghim misaze bresi layer hayte avalie kh rahat --> mitoni shabake haye kh amigh besazi
#
# - resnet18
# - resnet34
# - resnet50
# - resnet101
# - resnet 152
#
# batch normalziation ,,....

# %% [markdown]
# YEk tarikhche va yek fahm -> shoma yad migirid
#
#
# Yk hafte ham zaman hast
#
# do jalase ghabli ---> Neural network tutorial (mineveshtan)
#
# Jalse ye ghabli --> pytorch tesnorflow --> hal mikrdn
#
# ijn jalase --> In chandin shabake ro baram ch .md word baayd yasd bgirid va bfrstid , youtube ,...
#
# hadeagahl rozi 2,3 saat zaman bezarid
#
#
# CNN , sequence mdoels and RNN (chera niaz darim? , chie ? chijori code zani) , LSTM (moshjeli rnn) , GRU(kh kam kh kam) ,
#
# Autoencoder (encoder, decoder)
#
# Variational autoencoder (VAE)
#
# GAN (Gnerative adversarial network) --> ejaze mide shoma pormpt --> tasvir geenrate
#
#
# Attention mechanism (negahe koli behesh bendazid)
