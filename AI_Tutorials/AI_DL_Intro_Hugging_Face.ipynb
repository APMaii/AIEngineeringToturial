# %% [markdown]
# # Hugging Face
#
# Bebinid man yad gereftam algorithm haye mokhtalef ro va ba mesal ha didam cheghadr ina karbord daran, Machine learning (ML) , nEURAL NETWORK , CNN , RNN, LSTM, Autoencoder ,..... yad grftim .sequence2sequence,
#
# Transformers ina kh pichide mishan --> man betonam az base benevsiameshon --> ama datahaye ghool mikhad --> billioni --> dastresi nadari, jaei baraye zakhriash nadari . bad 200 terabite --> 10 ta GPU dari modele transformer rooey ina train bedi --> 3 mah , 4 mah 5 mah tool mikeshe
#
# chon baba az beyen billlion ha jomle --> 'Decoder only' betoen self attention weigth bais --> rabetey beyne jomle haro befahme -> betoen jomle sazi , fael ,... (1)
#
# (2) betoone javabo befahme, capital france --> paris . wikipedia . fahme estedlal dashte bashe
#
#
# mesle lstm , rnn, neural newtork --> Pytorch / tensorflow hast dostan baraye sakhte yek model , baraye training , baraye inference (estefade) krdn.
#
#
#
# Hugging face
#
#
# ![hugging_face](https://camo.githubusercontent.)
#
#
# Chand farnasavi sale 2016 , yek hugging face --> aim -> sakhte chatbot baaye teengers
#
# 2017 --> attention, self attention, transformers
#
# 2018 --> yek ketabkhone -> transfotmer va donyaro terkonid -> monafejr shod

# %% [markdown]
# in sherkat omad gof , bebin shoma agar train nakhay bokonu, az model haye transformer fght estefade koni , baayd begardi, modelo peyda koni . mdoel pytorch . .save() --> save file haye  okhtalef , weight ha (vazn hae k train shdoe) , bias (train shdoan) gigabyte zakhire shdoan. memari e dare, CNN --> 2 ta laye CNN , 5 ta laye , resnet kenare CNN yek residual connection memari motefavet 0-> memarish ,... save shodash --> peyda mikrdi
#
# mojadad ba pytorch ono misakhti, weight o bais ro load mikrdi --> bad taze bad azz 400,500 khat mitonesi azash estefade koni rooye gpu/cpu khodet .
#
#
# Huggingface gof man miam yek Hub misazam baraye tamame model haye transformer , yani transformer, harchi fk koni, CNN , RNN, LSTM , Transformer --> (natural language processin , text to text , text generation, audio to text , text to audiuo , voice to vocie, text to picture, image to text , image + text --> text , )
#
# man yek hubam , github toosh file hate pythono .. cod enevisie , hugging face --> hub hastam baraye tamame in model ha .
#
#
# pas yek website e aval -->
#
# ![https://huggingface.co](https://huggingface.co)
#
# sign up e hugng face (ba tasvir ) chegone shoam sign up konid
#
#
# dar navbar e bala , yek chize dar ebename Models, Datasets, spaces
#
#
# Models --> vaghty varesh beshi hamchin safe ei hast
#
# mibinid 3 million models dare, ama man mitvaanma az samte chao inaro filte rkonm . masalan text geenration , any to any
#
#
#
# ina harkodom , mnesbat b type  k daran .
#
# text to text
#
# text to text --> input outout --> mdoele ba yek memarie pichide transformer rooshon train , amade hast --> vorodi text --> ouput text
#
# azash use koni
#
# image to text 0--> image caption --> mdoel transfortmer train dadan,. image --> tyext
#
#
# image - text --> text ....
#
#
#
#
#
#
#
#
# https://huggingface.co/docs/huggingface_hub/index
#
#
#
#
#
# GPT --> million aprametrs, 1 B , 2 B
#
# lamma (meta)
#
# Phi (microsoft) --> 7 B parametr
#
# 7 billion ha m roye ram 8 g , 16 g nemitonan javab bdn doros --> aslesho estefade konid
#
#
# GPT --> 20 B , 30 BV
#
# 500 B , 1 Trillion parameter,
#
# GPT -> 1 trillion --> alsish
#
# gpt2 --> milluion --->
#
#
# Hugging face --> yek jaei hast k koli model dakheelshe
#
#
# hala k raftim dkahelesh hame detail ro didim , mitoni bezani
#
# use this mdoel --> ketabkhone (transformer) , local app (llama) --> youtube tadris --> hamin mdoel ha local ejaze mdie run bshe , bedoen naiz b internet , roye local (laptabe)shoam eja mishe
#
# GPT ,.. -->website app e goshi --> GPT MODEL , run bshe ro hamchin, rooye yekseri servr az sherkate openai run shodn, matn mfirsiu-->onja process-->barmigrdone
#
# ma model haro --> local run konim (roye laptabe) --> model haye 2,3 Billion aprametr
#
#
# Transformers
#
#
# Az model -> app dari ,local, server 2 G , 4 G . man poool bdm beehsh , plan haye hemayati dahste 500 ta to roz trayhgan, servere taraf run bshe in modele k man bkhm , websit serveram bala
#
#
# text usere man --> servere man run bshe (2g, 4g, 32g server)
#
# text usere man -0-> servere --> provider (onaj run bshe) --> servere --> useram  (inference providers) --> Deploymnet (Grok, cloudflare ,...)
#
#
#
#
# ```bsh
#              Hugging Face
#                    │
#         ┌──────────┴──────────┐
#         │                     │
#        Hub                Libraries
#         │                     │
#    Models                transformers
#    Datasets              datasets
#    Spaces                tokenizers
#                          diffusers
#                          evaluate
#                          accelerate
#                          peft
#                          trl
# ```
#
#
#
# Pythonic estefad konm niaz b libraries (API) vasl beshge b hub va biare too laptabe khodem, hugingface baraye inakr omd do ketabkhoneye keyli ohemio dad --> transformers, datasets --> sal haye badi diffusers, evaluate, accelrate, poeft, trl ,.....
#
#
# datasets---> vasl shodan b hub dataset Hugging face
#
# Transformers --> avsl shodan b oon model ha hast
#
# Hugging face --> Hugging_Face_Beginner.ipynb -->
#
#
# chizi k vagheiat hast --> yani practical use mishe -->
#
#
# # tokenization --> Text --L> tokenzie ->< token token
#
# modle haye besiar ziadi darim
#
#
# Kheyli dostan moshekl dare --> yek envuironeemnte jadid besaazid fght baraye transformer --> hugging faxce 2018
#
# fresh environemnt
#
# pip install -U numpy accelerate transformers
#
#
# ```python
# from transformers import AutoTokenizer
#
# tokenizer = AutoTokenizer.from_pretrained('google-bert/bert-base-uncased')
#
# text = ' i love aritifical intelligence'
#
# toens = tokenizer.tokenize(text)
#
# print(tokens)
#
# ```
#
#
# ```bsh
# [
#     'i',
#     'love',
#     'artificial',
#     'intelligence'
# ]
# ```
#
# b token tabdil mikone
#
#
# text --> token --> Transformer
#
#
# tokenzier ha kh bastegi dare b hdoe transformer ha yani ina beham mortabet hastan
#
# baayd tokenziewri estefade koni k tranasformere mikahd. transfformeer bar dataseeti train dide k tokenziesh hanonjori.
#
#
# ```bsh
# Raw Text
#    ↓
# Tokenizer
#    ↓
# Token IDs + Attention Mask
#    ↓
# Model
#    ↓
# Raw Output / Logits
#    ↓
# Post-processing
#    ↓
# Human-readable Result
# ```
#
#
# mitonam tamame in kar ro ba yek chizi bename pipeline anajm bdm
#
# ```python
# from transformers import pipeline
#
# #task -> onaj filter mikrdi
# classifier = pipeline('sentiment-analysis',model='distilbert/distilbert-base-uncased-finetuned-sst-2-english')
#
# #in miad mire oto in site (api) download krdne distilbert/distilbert-base-uncased-finetuned-sst-2-english rooey lcoalet hame chizaro .config. .weigth o... downlaod mikone
#
#
# classifier('this is fantastic!')
# ```
#
# ```bsh
# Positive 0.9999
# ```
#
#
# Question ansxwering
#
# ```python
# qa = pipeline(
#     "question-answering" , model='dddddds'
# )
# #tool miekshe yekabr downlaod mikoen Gigabyte
#
#
# #question, ocnetxt
#
#
# result = qa(question ='when was hugging face founded?',context='ugging face was foudned in 2016')
#
# print(result)
#
# ```
#
#
#
# #voice TO  text
#
# ```python
# asr = pipeline(
#     "automatic-speech-recognition",
#     model="openai/whisper-small"
# )
#
# result = asr(
#     "audio.wav"
# )
# ```
#
#
#
# ```python
# classifier = pipeline(
#     "image-classification",
#     model="google/vit-base-patch16-224"
# )
#
# classifier(
#     "cat.jpg"
# )
# ```
#
#
# ```bsh
# Egyptian cat     0.84
# tabby            0.11
# ...
# ```
#
#
# #tokenizer -> autotokenizer
# #model --> automodel
# #hame nianro beham vasl koni --> Hugging_face_beginer
#
# ```python
#                      pipeline()
#
#                          │
#           ┌──────────────┼──────────────┐
#           ↓              ↓              ↓
#
#      Preprocess         Model       Postprocess
#
#           │              │              │
#           ↓              ↓              ↓
#
#       Tokenizer       BERT          Softmax
#
#       Tokenizer       GPT           Decode
#
#       Processor       ViT           Labels
#
#       Processor      Whisper        Text
# ```
#
#
#
#
# # Transfer learning
#
# ta inja Usage in mdoel haro yad grftid , nahayaat ba hugging face --> Modelo API downlaod , estefadde mikoni
#
# ama age khdoet modeli bekahy az sefr besazi scratch --> pytorch /tesnorflow --> naiz b dataye kh ziad, va naiz b computation , .....
#
#
# Transfer learning
#
#
# CNN --> ma chnadidn layer darim, omadan Resnet 100 layers --> omadan az ebteda rooye 1 billion ax train dadan, layera vaal tasviro tashjlhi midan, layer haye vasat , edge haro , layer haye 4,5 object, cheshom dahano  gehmaat , ta entehash k fvasl mishe be yek neurla network --> clasifictaion --> 1000 ta class tabdil --> ensane, relephoen, miz , .....
#
# shoma baraye kare khodet mikhay yek image neurla network, CNN besazi k kolan 4 ta chizo tashkhi bede, dame dare khoen, mashino tashkhis bede, ensan (2 ta chiz) va datahash , 1000 ta bishtar nadari
#
# nemitonam in Resnet (CNN) --> layer haye avalie , 90% layerham --> assan kari ba dta --> rooye 1 billion aprametr train bbinan --> ehtemale ziad, vaghty man axi bdm , too layer haye avalie -> aval drn obejcto detect mikonan , bad edge haro , corner haro , gehsmat haro ,.. --> hamasho begriam fght biam layere akahro beja inke b 1000 ta label vasl kojm, b dota label vasl konm (mashin, ensan)
#
# kole layer ha freez konm, do layerre kahar trsinable konm va bezaram train beshe--> Transfer learning
#
#
#
# model haye base --> huGGING FACE
# pytorch --> transfer learnign ro anjam midan
#
# Pishrafte
#
# Transafer_learning.ipynb --> dar ekhtiare dostan
#
# language models --> 1 billion parametrs, mojadad , fgth concept khodemon ro , datahey sherkate, soal javabae marbot be karet train bdi
#
# 1 bILLION PARAMETR, yek mdoel base --> migiri --> besorate khas fght 90% freez mikone wieght (hamonaei) ina yad ggrftn grfnt dostan va LLora (adaptor) ejaze mdin k shoam az oon LLM ha besorate khas fght baraye ataye khdoet dahste bashi--> fine tuen krdi kole model ro rooye datahaye khodet
#
#
# hamchnin yek chize dg e ham bename quantization
#
# Model haye 1B 2B --> vaghty bkhan rooye server ya laptab runbshn -> ian weightashon ,--> 32 bit , 16 bit --> ram zakhri emsihe
#
# choon serverwa ha laptab ha zaeifan --> yek ravesh vojod dare--> quantizatin--> precision in weigth haro kam kon --> 32 bit -> 4 bit
#
# accuracy baid opaein --> ejaze mdie ina run bshn rooye laptaba ya ... --> quantization yek approache hot va terekide market va
#
#
# huging face--> tahe yekseri mdoel ha nevehste q4b   quantize4b
#
# model_GLM5.3_8B parameter
#
# model_GLM5.3_8B_q4b
