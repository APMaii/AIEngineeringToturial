# %% [markdown]
# # AI Deep Learning OverView
#
# Ma shoro kardim ba yek file bename Python review --> omadim python ro az ebteda mohem tarin nokatesho goftim , overview kardm va badesh ham advanced functions o chizhaei k lzem bod gofte shod. (AI_Python_Review.py)
#
# Badesh dar morede Advanced OOP --> bekhatere inke hamye class ha k badan estefade krdim dar sk learn o scipy pandas pytorch hame class bodan
#
#
# CLI Shell --> AI_CLI.md --> Hatman niazi nist az GUI estefade beshe -> Devops -> Jaalaseye (deployment)
#
# Github o Git tadris -> ai_git
#
# Telegram bots
#
# ai_cli , ai_git , telegram_tutorial/ --> Devops
#
#
# Libaries that we need :
# - Numpy --> Arrays , linear algebra numerical computaton --> AI_NUMPY.py
# - Matplotlib --> visulaizaion and graphic --> AI_Matplotlib.ipynb
# - Linear Algebra --> vectors , marices for AI --> AI_Linear_Algebra.py
# - Calculus --> Derivatives, gradients, optimization --> AI_Calculus.py
# - Numerical Methods --> Numerical methods -> AI_Nuerical.py
# - Scipy , Sympy
# - Pandas --> Data analyzis and data clearning --> AI_Pandas.py , AI_Pre_Processing.py
# - Statistics --> ghabl az inke varede machine learnign beshid niaz darid k startistic bdanid , distribution, probability , statistical tests (Hypothesis Test, ANOVA) -> AI_Statistics.py
# - Linear Regression --> Besoorate amari yek regrassione kahti ro fahmidim --> AI_Regression.ipynb
# - Introduction to machine learning --> AI_ML_Intro.ipynb
#
# Ta inja ma yad grfte bodim ke advance ba python kar konijm , numpy baray emohasbeat, matplotlib , seaborn baraye visulaziation, va ma yek seri essential topiuc ghabl az ML , DL yad grfte bodim  mesle linear algebra, calculus , numerical methods ke ma  az Sympy and scipy estefade mikardim (ghalbe mohasebate ML, DL)
#
# badesh Pandas ro yad grftim ke betonim datamon ro az csv, xlsx , json ,... biarim dakhele python besoorate dataframe , badesh taghirat bedim, bahash kar konim va hatman clean konim k prepared beshe baraye further process.
#
# Statistics --> Ghabl az vordo be ML ma midonestim ke amar chist , distribution chie, distribution normal , ... , Hypothsis Tezt , H0 , H1 bar asase alpha yekodomo reject mikardim .. Z test dashtim , t student test , ANOVA --> bema migoft kodom feature ha tasir daran rooye khoroji . Pearson dashtim ke correlation beyne parmater haro besorat ekhati behemon migoft.
#
# ama ma donbale rabetey khatie beyne x (vorodi ha) va y (khoroji) bodim va baraye bedast ovrodanesh niaz dahstijm be regression paas regrassione khati ro yad gereftim besoorate amari.
#
#
#
# Tamame donya ro mishe b yek masaleye **input-output** tabdil kard , nesbat be data ei k darim , Machine learning
#
# Machine mesle yek ensan az data learn kone (logico) , bad az training , fitting (learning) logico bedast ovord, bar asase oon tasmim begire v aamla kone .
#
# X dashtim , Y ham dahstim --> Supervised regresssion -->  Y continious -> Supervised ML Regression , Y gosaste --> Supervised ML Classification <br>
# X dashtim vali Y nadashtim , Clustering --> Unsupervised Regression <br>
# X dahstim Y dahstim ya na  , ama datamoon kheyli ziad bood --> Deep Learning (DL) mishodim <br>
# Age x, y emon az ghabl amade nabod va dar mohit mikhastim shoro b learning konim done done besorate peyvaste data vared mishod -> Reinforcement learning (RL) dashtim<br>
#
#
#
# - intro on Machine learning : AI_ML_Intro.ipynb  --> train test split
# - Machine learning models (Classifieer, regressor : KNN,DT , RF , SVR) : ML_Models.ipynb
# - Protocol va gridsearch, yekseri parmater darim k learn msihe yekseri parametr darim k bayad az ghabl khdoemon taein konim va in aprametr ha dar farayande elarning ( accuracy ,.) tasir gozar hast pas bayad in hyperparmaetr haro tune konim -->  hyperparametr tuning konim with cross valiation  AI_ML_GridsearchCV.ipynb
# - Feature engineering --> Process konid data va oprepare data before mL pipeline --> AI_Feature_engineering.ipynb
# - Machine elarnign --> Pipeline --> hame chio , preprocessor , ML , post process --> PIpelieb -> AI_ML_Pipeline.ipynb
# - Unsupervised learning --> K cluster , clustering, DBSCAN --> AI_ML_Unsupervised
# - Jalase dahstim baraye hale masaleye Machine learnign --> Real example of supervised regression and supervised clasificatin and unusopverised ML --> AI_ML_Examples.py
#
# - Reinforcement Learning --> ma datahamon amade nist balke besorate peyvaste hey varede system mishe va ma bayad yek systemi besazim k ba algotrithm system padash bere jolo yad begir e, padasho mojazat , hey in agent (systm) ba mohit  (environment) interact , agar doros karesho anjam bede behssh reward , dade nemsihe (0,1) , bar asase policy , logici kasb mikone va bar asase policy decide mikone . AI_RL.Ipynb ((Coming Soon))
#
# - Neural networks --> AI_Neural_Nets_Intro.ipynb -> Neural netgwork ha chist va
# - Deep learning introduction --> AI_Deep_Learning.ipynb
# - Deep learning in details ( activation, loss , optimizer, cocnep in neural network) AI_Deep_Learning_in_details.
# - Deep learning coding --> all notes egarding pytorch , tensorflow exampels
#
# **Neural network** chizi hast --> paye tarin haalt --> feed forward neural network, Neural Netrowk (NN), fully connected neural network , Multi layer perceptron (MLP) --> in yek memari hast k input layers, hidden layers, output layers dare. Input layer bastegi dare be tdade feature haye ma , hidden layer yek hyperaprameter , harchi bishtar amigh tar, output layer -->  bast eb masale ei k darim, regression 1 done ei , classification binary 1 neuron , multi label clasification b ezay ehar label yek neuron dairm.  in concept chie . kamel goftim ke kolsho az aval k batch batch mikonim. tooye har iteration (har yek batch) data ro yekbar midim dajkhelesh , Feed forward --> va zarb dar wieght ha bais ha mishe , mirese output ro pishbini mikone, dar ebtda weigth ha va bias ha random haastan pas yek adade kheyli part va door pishbini mishe, yek loss fucntion darim k falsey ebeyne poishbinio vagehiat ro hesba mikone, back propagation mizanim, yani darsade khataye har node (neuron ) ro az khataye kole output layer hesab mikonim bahash ba chain rules moshtaghe loss bar har weight va bias ro az akahrin layeer --> hidden layers -> input layers --> back propagation ro anjam midim -> moshtaghe loss /weight ya moshatghe loss / bias ro darim. Optimzieri k darim ma update mikone weighte maro w_new hamn w_old + learning rate * in moshatghe va yek iteration anjam mishe. Kole datmon b batch taghsim shode, hame batch ha anajam bshe --> kole iteration -> epoch . dar chandin epoch dar enteha neural networkemon yejseri weight va bias dare ke kheyli aghighan, zmani k vorodi midi mire too layer ha k har layer az neuron ha hast , k outpute ona * weight + bias sum mishan va miran zire yek activation fucntion (non linear) va dar enthea outputio k bema midan kheyli kheyli nazdi b vagheiat hast (lossemon kochik mishe --> hadafe optimizeremn) neural networke nahaei ke ma darim.
#
# Goftim k neural network limitation haye khodeshon ro daran . Yeki az in limitation ha bahse tasavir hast
#
#
#
# ----
# ----
# ## Image Processing
#
# Image haro darim --> pixel x pixel hastan --> flatten  konid va bedid be yek neural network, ama nazme fazaei va ordere pixel ha az beyn mire , pas omadan goftna biaym az CNN estefade konim .
#
#
# Classical Machine learning --> Miomadan yek tasviro ke dashtan az ebtda --> midadan be yek ketabkhone ei (OpenCv --> CV-> Computer vision) --> miomadan va azash feature extract mikardan --> tedade labe ha , tedade khotot , mohit , roshanaei , tedad epixel siah , tedad epixel sefid -> Meesal breast cancer dataset --> az tasavir CT scan --> 31 featur ekshidim biron
#
# jadvale excel --> Machine elarning mdoels
#
# Data(image) --> Feature extraction (opencv) excell --> ML Models --> Output
#
# Modern Machine learning
#
# tedade data ha ziad shdo, memari ha psihrafte shodan -> CNN --> convolutional neural network --> Kernel bezarim bar sare rahe axe avalie --> maxpooling, avgpooling --> va haminjori featur eha keshide mishe biron, har laye featur ehaye khdoesho , edge , detaol detail tar ta berese be yek fuly conected (classification) --> ina dige niazi b featuee extraction
#
#
# Image directly b network miadadi
#
# data(image) ---> Neural Network --> Output
#
# Ama na tanah baraye classical machine learning , balke shoam vaghty yekseri ax dari --> resizesh kone , rango taghiri , filter roosh bezari , tedadesho ziad (data augmentation) --> micharkhonan bar ax mikonan --> picture generations . yek azx dari bayad **Object detection** tashkhsie tasvir --> yek axe az machine ha --> az oon tashkhis bedi pelake machino .
#
# hoshe masnoei afrad aya da rmashin sigar mikeshan ya na . axe dorbin too har ax , mashin haye ziadi -_> done done tashkhis dade beshe mashin ha , crop bshe oon axo bede b Neural network (CNN) besazi --> open cv estefade mishe
#
# tabdile video --> frame frame --> tasavir --> loop bezani dakhelesh --> OpenCV.ipynb
#
#
#
# - AI_CNNs.ipynb --> Convolutional neural networks ham tadris shdo .
#
# Yani Neural networks yekseri limtiaiton va masaln dare bahse ocmputer vsiion bahse pxiel order o nazme fazaeie tasviamon--> kernel --> CNN -> sahhtah
#
#
# ![cnn_archiytecture](https://media.geeksforgeeks.org/wp-content/uploads/20260217113409515144/working_of_cnn__.webp)
#
# Neural newtork --> fully connected neural newtrok, CNN
#
# - Sequential data shod , zamani k price haro darim dar roozhaye mokhtale , time stamp , jomle , signal , ...--> Recurrent neural network (RNN)
#
# Recurrent neural networks --> omad goft yek jomle k dari , bia done done bhem bede, x1,x2,x3,x4,x5 bejaye inek neural newtork hame inaro baham mide . bad miomad yekchzii bename H (hidden state) mohasebe miakrd , az aval miomad x1 --> neural newtrok --> output midad (mohem nabod) ama hidden statei midasd benane (h1) . in h1--> networke dobare , va dota vorodi X2  + h1 --> miraft into ....__.> x e akahr psihbini mishod
#
# ```bsh
#
# x(t) ---->   |----------| ----> Y(t)                |--------|
#              |   RNN    | ---> h(t)       h(t)--->  |  RNN   |-->y(t+1)
# h(t-1)---->  |----------|                 x(t+1)--> |--------|--> h(t+1)
# ```
#
#
#
#
#
# ![rnn_architecture](https://www.mdpi.com/drones/drones-07-00026/article_deploy/html/images/drones-07-00026-g001-550.jpg)
#
#
#
# vorodie aval varedeyek neural network mishe , yek khoroji mdie ghabl az outpute nahaei . khrooji dota shakhe msihe -> y(t) hamon lahze k kaeri nadarim ebehsh , h(t) --> rikhte msihe roye network. hamon entwork ba hamon weigth bias (weigth shairng) , hala x e badi varede network miseh vasate kar ba in hidden state jam mishan --> y(t+1) k va unjkari nadarsm, h(t+1) --> nex network ---> ta x(t+n) --> vared mishe ba h(t+n-1) --> h(t+n) , y(t+n) ->y --> pishbinimoon akharie
#
# I love deep --> learning
#
# dollar 24 shahrivar, 25 shahrivar, 26 shahrivar --> 27 shahrivar
#
# audio
#
#
# yekjori toonestim yek memroy dahse bashim dar datahaye sequential --> Pas ma ab hiden state (short memroy ) dashtim
#
#
# AI_RNN.ipynb
#
#
# - NLP --> Natural Language Processing --> AI_NLP.ipynb
# - ketabkhone hast --> pishrafte tar , AI_NLP_Libraries.ipynb --> advanced -> dar ekhtiareton mizaram
# - Signal_processing.ipynb , audio dar taraf hastim , sequential , yek audio --> wave --> Ba yekseri filteer --> yek adad va audio processing , liborsa --> va az in ketabkhone estefade mishe --> Signal_processing.ipynb
#
# Computer vision (binaei machine) --> Opencv file , CNN
#
# NLP (natural language processing) -> RNN, .... , NLP , ,AI_NLP_Libraries.ipynb
#
# Audio , Signal processing --> Signal_processing.ipynb
#
#
# We have limtiation with rnn --> vase sequence haye kootah javab bod , ama agar sequence tolani mishod do moshekl bod . moshkele 1 inke input haye nahaei tasire bsihatri bar output dasht va injori forget msihod input haye avalie , Exxplding/vanishing grasdient.
#
# in hidden state (short memroy) kafi nist ma yek new path baraye long term memory --> short term memoryy valong term memroy
#
# - Long Short Term Memory (LSTM) --> AI_LSTM.ipynb
#
# zir banaye model haei k ham Hidden state ham cell state daran. 3 ta gate darim, forget gate tamsim miugire chia forget beshan, input gate --> chia vared bshen , outptu ghate -_> chio onlahze bede biron. Hidden state (short term memory) daghhigan mesle RNN, cell state (Long term memory) ijja ba gate ha managesh mikone pas khob in mitone az ghabl ro dashte bashe datahaye kh kh az ghabl va exploding/vanishing ro dta hadi ok kone
#
#
# - Autoecndoer --> encoder decoder --> image ya harchizi neural network -_> kochikesh moikrdim , bedone lose infromation, compress konim kole dataro , bargardoonim . va ba loss fucntion --> diferent autoencodeer AI_Autoencoder.ipynb
#
# - Vali moshkel in bod k z ttasadofi, hatamn image e vaghei nnmigiri , generators , Variational aUTOENCODER --> LOSS FUCNTION, LOSS RECOSTNRUC -> FORCE network ro k moratab latent rperesnetation ro besaze
#
# - AI_DL_GAN --> Genratiev adversial newtork --> dota network dashtim , yek network generator , discimiantor --> takhasomi reghabat miakrs -> paye e bar model haye Diffusion --: generatior --> autoencoder, VAE , GAN --> CNN --> image estefade mishe.
#
# rnn , lstm  , encoder-decoder (seq2seq) , transformer --> sequential data (text , audio)
#
# - AI_DL_Example_tutorials.ipymb , AI_DL_Exampel_Notes.ipynb
#
# Autoencoder.example.py , VAE_Exampel.py VAE_Example2.py , RNN_example.py , LSTM1,LSTM2,LSTM3,LSTM4.pyt ro hal krdim
#
#
# ```bsh
#
#               Neural network
#                      |
#         ------------------------------
#         |                            |
# CNN, Autoencoder              RNN, LSTM ,Seq2Se2, Attention, Transformers
# VAE, GAN , Diffusion
#
# Computer vision                    Sequential data
#
# Opencv,...                       NLP (natural language processing)
#                                         Signal processing
# ```
#
#
#
#
#
# dar file seq2seq.ipynb ro shoro konam
#
#
# RNN --> LSTM --> Seq2seq --> Seq2Seq with Attention --> Transformers
#
#
#
#
# Neural NETWORKS --> 1960 --> Omade , riaziatesh , neuron , Perceptron, multy layer perceptrons , First winter of AI, second winter of AI
#
# 1980 -2000 --> Machine learning algorithm ha oomad .
#
# Convolutional neural networks (CNN) --> 2010 , koli memari , Resnet ,....
#
# RNN, LSTM  Cell --> avaliashon --> 1980
#
# Deep RNN, Deep LSTM , neurla networki k bar paye ye in cell ha bashe --> 2010 ,
#
# 2012 --> Alexnet (CNN) --> GPU run koni (CPU run mishode)--> pishrafte bozorg
#
# Ta 2014 hamechi okk bood --> Translation
#
# Dakhele file  badi sohbat mishe
