# %% [markdown]
# # Ai genrative models
#
# fhamidim k autoencoders ha --> Encoder - decoder bodan . mitonnan yek vorodi begirand tabdil koann b yek latent
#
# ![autoencoder](https://theaisummer.com/static/d57a2ae3fb095d80d99d4cca1635362c/3d2b2/autoencoder.jpg)

# %% [markdown]
# ma kolan estefade ee k az autoencoder kardim fght az parte encoderesh estefade mikonim
#
# Image hamon ya ahrchizio midim encodder -> encode mikone be yek latent represnetationi k kole infromation ro keep mikone ama ba tedade numebre kamtar
#
# signal procesing, computer vsiion, lamguage processing, feature engieering estefade mishe.
#
#
# encoder-decoder -> moshkel --> encodere khali estefade konim. shgabakamon yek encoder bood --> khoroji latent -> ba chi moghayesasm , reference -> backpropagation update wiegth haye random .
#
#
#
#
# aYA AZ decoder nemsihe estefade krd??
#
# ```bsh
# 784
#
# 128
#
# 64
#
# 32
#
# 2
#
# 32
#
# 64
#
# 128
#
# 784
# ```
#
# auto encoddre -> MNIST axaye dastkhat adad -> yad bgire
#
# model.encoder(image) --> 2 adad k kole infromation in toe
#
# har axi ro man mitavand ba do adad  x y namayesh bedam
#
# ```bsh
#
#    •••
#
#
#                     ••••
#
#
#          ••
#
#
#                             •••
# ```
#
#
#
#
# model.decoder(adade dotaei) --> 2 --> 64->128-->784 --> image behem tahvil
#
# bordare dotaei bedam --> random [10,34] -->  yek ax generate kone?
#
#
# yek soali k maro be samte generative mdoels ha bord
#
#
# Moshkel injas k --> latent space --> monazam nist , elazaman monazam nist
#
# hadafe loss, shabake (network) in bode k fght 784 --> 2 ta adad . koja bashan chand bashan . information ro compact kone
#
#
# age shoam y adade random vrdari yejae k khali bashe
#
#
#
# ```bsh
#
#    ••X
#
#
#                     ••••
#
#
#          ••
#
#
#                             •••
# ```
#
# age x RO VARDARI . ADADE 7 bodoe tabdil shdoe inaj bva khob bzni hamono axe image 7 ro namayesh mide
#
# empty cell vardari
#
# ```bsh
#
#    •••
#
#
#            X          ••••
#
#
#          ••
#
#
#                             •••
# ```
#
#
# X --2 --> 64 --> 128 --> 784 zarbdar --> outptu 784 --> yek ax mide--> axe hatnman mani dar nist
#
# choon too latent space asan chizi tarif nashdoe
#
# random behet mide
#
# yek chizi besazim --> agar yek chize random dadidm --> bere bara ma random image generate kone -> image hae k shabihetraining dataset bashan ama too training dataet vojod ndashte bashan.
#
#
#
# # Variational Autoencoder (VAE)
#
#
#
# man inja --> to losse auto encoder chi migid
#
# MSE (output - input)
#
#
# fght network ro force mikoni k chikar kone , fght 784 -> 2 --> 784
#
# 784 avali ba akahir shabihe ham bashe
#
# kole hadafe network ine betone doros reconstruct kone
#
#
#
#
#
# tooye VAE --> na tanha inkaro kone , MSE bashe, balke biad bege vaghty mikhay 784 --> 2 . bayad oon latent spacet ham moatab bashe
#
#
# yani bejay efght yek noghte --> yek distribution (tozi) dashte  bashim gussian . va ina bayadhamdigaro pooshesh bedan --> jaee khali namoone toye latent space
#
#
# loss --> dot ahadaf Lreconstruction + L KD
#
# L reconstruction --> mse autoencodeer --> force network khob reconstruct kone
#
# L KD --> majbor mikone dar kenare in shoma bayad;laytent spacet ham moratab she
#
# ![vae](https://theaisummer.com/static/25f603171034d2fc8f6a518b8537f85a/3f3b9/vae.png)

# %% [markdown]
# har noghte too latent , yek miu (miangin) , standar deviation -> tozi misaze bejatye yek nogthe . va in toiz ha bayad be gonei bashan k baraye har ax ham digaro betone poshesh bde.

# %% [markdown]
# networke nahaei k misazi
#
# ```bsh
# 784
# ...
# ...
# ..
# 2
# ...
# ...
# ..
# 784
# ```
#
#
# yek sampling koni az oon mianguino standard deviatuion koli --> ejaze mdie --> decoder (adad)--> image k misaze
#
# inja mani dar hast . latent mroatabe , random nist , empty nist .
#
# adade randomi mziani --> adade nazdike 7 , 8 ,
#
# hich gone axi too training dataset nadarim k shabihes bashe
#
# 7 ziad darim 100 ta 7 darim .
#
# 7 --> distribution

# %% [markdown]
# ![vae-exampl](https://houxianxu.github.io/assets/projects/dfcvae/web_faces.png)

# %% [markdown]
# paye o asase -> Generative adversial network (GAN)
#
# diffusion models
#
#
#
#
# Number random --> decoder 2--> 784 pixel (ax)
#
#
# text -> token --> cat is walking in park --> [cat,is,waling,in,park] -->[3323,23232,3223] , [3323,322332,3223]
#
#
#
# oon latent represnetatiuon --> image

# %% [markdown]
# ## Variation aurtoencoder mathematic in details

# %% [markdown]
# Jalse badi
#
#
# Azizan
#
#
# lazeme --> morore in mataleb hast
#
# ### jhalase beyne hafte (hale tamrin)
# ->> RNN, LSTM , Autoencoder , GAN (koli tadris konim)  , Seq2Seq
#
# Hale masale + do mabhas
#
#
#
#
#
# ### jalase akhar Official (jome ei)------
# Transformers
#
# Transfer learning (hugging face)
#
# pre-trained estefade konim
#
#
# NLP libraries, Computer vsiion librarie, signal procesing libraries
#
# Reinfrocement learning
#
# referwnce edame ye rah
#
#
#
# Tamrin entehaye dore ro ham elam mikonim
#
#
#
#
#
#
#
#
#
# ### Jalse unofficial (ekhtiari)--------
# Implementation harf mizanim
#
# modle haei k misazim ro chijori implement konim
#
#
# dataabase ha chian -_> overview database
#
# overview az django, fast api --> ina chian
#
# model ha chegone dar ch platform haei --> gahrar begiran
